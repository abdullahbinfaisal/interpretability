# %% [markdown]
# #### Setup

# %%
import torch
import torchvision
import timm
import os
import matplotlib.pyplot as plt
import torch.nn as nn
from einops import rearrange
from tqdm import tqdm
from overcomplete.models import DinoV2, ViT, ResNet, ViT_Large, SigLIP
from torch.utils.data import DataLoader, TensorDataset
from overcomplete.sae import TopKSAE, train_sae
from overcomplete.visualization import (overlay_top_heatmaps, evidence_top_images, zoom_top_images, contour_top_image)
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR


from lib.data_handlers import Load_ImageNet100, Load_PACS, Load_ImageNet100Sketch
from lib.universal_trainer import train_usae
from lib.activation_generator import Load_activation_dataloader
from lib.eval import evaluate_models
from lib.visualizer import visualize_concepts
from lib.mlp import train_mlp, test_mlp, prune_weights, check_sparsity
from lib.invariance import InvarianceStudy


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.empty_cache()

# %% [markdown]
# #### Train MLP

# %% [markdown]
# Set Parameters

# %%
## Number of Concepts
concepts = 768 * 8

## Our Pretrained SAE
sae = TopKSAE(768, nb_concepts=concepts, top_k=16, device="cuda")
sae.load_state_dict(torch.load("./models/ViT_MLP.pt")['ViT'])


## Our Full ViT Model
vit_full = timm.create_model('vit_base_patch16_224', pretrained=True)

# %%
## Get the Train Loaders
inet_trainloader, image_dataset = Load_ImageNet100(transform=None, batch_size=64, shuffle=True, dataset_allow=True, train=True)
inet_testloader = Load_ImageNet100(transform=None, batch_size=256, shuffle=True, dataset_allow=False, train=False)
sketch_trainloader, sketch_testloader = Load_ImageNet100Sketch(transform=None, batch_size=4, shuffle=True, train=False)


trainloaders = {
    "INET" : inet_trainloader,
    "Sketch": sketch_trainloader
}

testloaders = {
    "INET": inet_testloader,
    "Sketch": sketch_testloader
}


## Setup MLPs and Optimizers
mlps = {}
optimizers = {}
schedulers = {}

for key in testloaders.keys():
    mlps[key] = nn.Linear(concepts, 100)
    optimizers[key] = torch.optim.Adam(params=mlps[key].parameters(), lr=1e-4)
    schedulers[key] = torch.optim.lr_scheduler.StepLR(optimizer=optimizers[key], gamma=0.5, step_size=1)

loss_fn = nn.CrossEntropyLoss()
epochs = {
    "INET": 3,
    "Sketch": 7
}
alpha = 1.0  #Sparsity Constraint

# %% [markdown]
# ## Training

# %%
# for domain in trainloaders.keys():

#     print(f"====> Beginning Training for Domain: {domain}")
    
#     for epoch in range(epochs[domain]):
#         train_mlp(
#             image_loader=trainloaders[domain],
#             mlp=mlps[domain],
#             optimizer=optimizers[domain],
#             loss_fn=loss_fn,
#             vit_full=vit_full,
#             sae=sae,
#             internal_map=image_dataset.class_to_idx,
#             alpha=alpha,
#             epoch=epoch
#         )
#         if schedulers[domain] is not None:
#             schedulers[domain].step()

#     torch.save(mlps[domain].state_dict(), f"./models/MLPs/mlp_vit_alpha1_{domain}_7ep.pth")
#     print(f"Domain {domain} MLP Saved")
# Out:
# ====> Beginning Training for Domain: INET
# Epoch 0: 100%|██████████| 2032/2032 [15:28<00:00,  2.19batch/s, loss=8.5324]
# Epoch 0 finished. Average loss: 101.9885
# Epoch 1: 100%|██████████| 2032/2032 [08:30<00:00,  3.98batch/s, loss=4.2550]
# Epoch 1 finished. Average loss: 4.3454
# Epoch 2: 100%|██████████| 2032/2032 [15:48<00:00,  2.14batch/s, loss=2.4734]
# Epoch 2 finished. Average loss: 2.4281
# Domain INET MLP Saved
# ====> Beginning Training for Domain: Sketch
# Epoch 0: 100%|██████████| 1146/1146 [00:50<00:00, 22.61batch/s, loss=20.5407]
# Epoch 0 finished. Average loss: 195.2722
# Epoch 1: 100%|██████████| 1146/1146 [00:52<00:00, 21.98batch/s, loss=10.7439]
# Epoch 1 finished. Average loss: 13.8518
# Epoch 2: 100%|██████████| 1146/1146 [00:51<00:00, 22.06batch/s, loss=5.8571]
# Epoch 2 finished. Average loss: 7.3724
# Epoch 3: 100%|██████████| 1146/1146 [00:49<00:00, 23.08batch/s, loss=3.9974]
# Epoch 3 finished. Average loss: 4.7621
# Epoch 4: 100%|██████████| 1146/1146 [00:50<00:00, 22.76batch/s, loss=3.0687]
# Epoch 4 finished. Average loss: 3.5995
# Epoch 5: 100%|██████████| 1146/1146 [01:24<00:00, 13.53batch/s, loss=2.6366]
# Epoch 5 finished. Average loss: 3.0377
# Epoch 6: 100%|██████████| 1146/1146 [00:45<00:00, 25.41batch/s, loss=2.9927]
# Epoch 6 finished. Average loss: 2.7231
# Domain Sketch MLP Saved

# %% [markdown]
# ## Loading

# %%
for domain in trainloaders.keys():
    mlps[domain].load_state_dict(torch.load(f"./models/MLPs/mlp_vit_alpha1_{domain}_7ep.pth"))

# %% [markdown]
# Pre-Sparse Accuracy

# %%
for domain in trainloaders.keys():
    test_mlp(
            image_loader=testloaders[domain],
            mlp=mlps[domain],
            sae=sae,
            loss_fn=loss_fn,
            vit_full=vit_full,
            internal_map=image_dataset.class_to_idx
        )
# Out:
# Testing: 100%|██████████| 20/20 [00:20<00:00,  1.00s/batch, loss=0.2800]
# Test finished. Avg loss: 0.2123, Accuracy: 95.67%
# Testing: 100%|██████████| 128/128 [00:04<00:00, 30.26batch/s, loss=3.2420]
# Test finished. Avg loss: 0.4777, Accuracy: 88.43%

# %% [markdown]
# Sparsification

# %%
sparse_mlps = {}

for key in trainloaders.keys():
    
    sparse_mlps[key] = prune_weights(mlps[key], k=1.0)
    sparsity, n_zeros = check_sparsity(sparse_mlps[key])
    print(f"{key} MLP Sparsity: {sparsity:.2f}")
# Out:
# INET MLP Sparsity: 99.83
# Sketch MLP Sparsity: 99.84

# %% [markdown]
# Post-Sparse Accuracy

# %%
for key in trainloaders.keys():
    print(f"Testing MLP: {key}")
    test_mlp(
        image_loader=testloaders[key],
        mlp=sparse_mlps[key],
        sae=sae,
        loss_fn=loss_fn,
        vit_full=vit_full,
        internal_map=image_dataset.class_to_idx
    )
# Out:
# Testing MLP: INET
# Testing: 100%|██████████| 20/20 [00:19<00:00,  1.02batch/s, loss=0.2277]
# Test finished. Avg loss: 0.2114, Accuracy: 95.57%
# Testing MLP: Sketch
# Testing: 100%|██████████| 128/128 [00:04<00:00, 30.77batch/s, loss=0.0014]
# Test finished. Avg loss: 0.3323, Accuracy: 92.13%

# %% [markdown]
# ## Visualization

# %%
study = InvarianceStudy(sparse_mlps=sparse_mlps)

# %%
study.print_all()
# Out:
# Class 0 ============================================================
# Domain: INET
#     Concept 606 -> 0.00151
#     Concept 4395 -> 0.00150
#     Concept 778 -> 0.00011
#     Concept 2640 -> 0.00010
#     Concept 2621 -> 0.00008
#     Concept 483 -> 0.00006
#     Concept 1411 -> 0.00005
#     Concept 3680 -> 0.00004
#     Concept 4206 -> 0.00004
#     Concept 2077 -> 0.00004
#     Concept 5492 -> 0.00004
#     Concept 1746 -> 0.00004
#     Concept 3304 -> 0.00004
# Domain: Sketch
#     Concept 606 -> 0.00520
#     Concept 4395 -> 0.00213
#     Concept 1611 -> 0.00170
#     Concept 1543 -> 0.00153
#     Concept 2621 -> 0.00055
#     Concept 3304 -> 0.00051
#     Concept 3736 -> 0.00047
#     Concept 1971 -> 0.00037
#     Concept 757 -> 0.00016
# Aggregated
#     Concept 606 -> 0.76745
#     Concept 4395 -> 0.56936
#     Concept 1611 -> 0.10914
#     Concept 1543 -> 0.09789
#     Concept 2621 -> 0.05885
#     Concept 3304 -> 0.04260
#     Concept 778 -> 0.03078
#     Concept 3736 -> 0.03004
#     Concept 2640 -> 0.02828
#     Concept 1971 -> 0.02354
#     Concept 483 -> 0.01625
#     Concept 1411 -> 0.01501
#     Concept 3680 -> 0.01292
#     Concept 4206 -> 0.01158
#     Concept 2077 -> 0.01112
#     Concept 5492 -> 0.01076
#     Concept 1746 -> 0.01028
#     Concept 757 -> 0.01020
#
# Class 1 ============================================================
# Domain: INET
#     Concept 521 -> 0.00194
#     Concept 136 -> 0.00163
#     Concept 4261 -> 0.00010
#     Concept 686 -> 0.00009
#     Concept 3304 -> 0.00006
#     Concept 2821 -> 0.00005
#     Concept 757 -> 0.00004
# Domain: Sketch
#     Concept 521 -> 0.00368
#     Concept 1971 -> 0.00246
#     Concept 4261 -> 0.00167
#     Concept 5594 -> 0.00062
#     Concept 136 -> 0.00027
# Aggregated
#     Concept 521 -> 0.79401
#     Concept 136 -> 0.48668
#     Concept 1971 -> 0.15777
#     Concept 4261 -> 0.13591
#     Concept 5594 -> 0.03962
#     Concept 686 -> 0.02640
#     Concept 3304 -> 0.01761
#     Concept 2821 -> 0.01335
#     Concept 757 -> 0.01291
#
# Class 2 ============================================================
# Domain: INET
#     Concept 92 -> 0.00212
#     Concept 2998 -> 0.00161
#     Concept 2028 -> 0.00029
#     Concept 3246 -> 0.00026
#     Concept 5469 -> 0.00023
#     Concept 1831 -> 0.00022
#     Concept 2308 -> 0.00013
#     Concept 3821 -> 0.00013
#     Concept 4721 -> 0.00011
#     Concept 5832 -> 0.00010
#     Concept 4080 -> 0.00009
#     Concept 1001 -> 0.00009
#     Concept 1893 -> 0.00008
#     Concept 5231 -> 0.00007
#     Concept 1226 -> 0.00007
#     Concept 1971 -> 0.00006
#     Concept 3625 -> 0.00006
#     Concept 448 -> 0.00004
#     Concept 5660 -> 0.00004
#     Concept 1905 -> 0.00004
#     Concept 4154 -> 0.00004
#     Concept 3715 -> 0.00004
# Domain: Sketch
#     Concept 92 -> 0.00700
#     Concept 2128 -> 0.00482
#     Concept 448 -> 0.00445
#     Concept 2998 -> 0.00393
#     Concept 1971 -> 0.00293
#     Concept 1705 -> 0.00113
#     Concept 1758 -> 0.00090
#     Concept 2621 -> 0.00087
#     Concept 4955 -> 0.00053
#     Concept 5461 -> 0.00045
#     Concept 2647 -> 0.00031
#     Concept 5636 -> -0.00119
#     Concept 3304 -> -0.00067
#     Concept 1611 -> -0.00042
# Aggregated
#     Concept 92 -> 1.05785
#     Concept 2998 -> 0.71578
#     Concept 2128 -> 0.30845
#     Concept 448 -> 0.29766
#     Concept 1971 -> 0.20571
#     Concept 2028 -> 0.08279
#     Concept 5636 -> 0.07617
#     Concept 3246 -> 0.07464
#     Concept 1705 -> 0.07246
#     Concept 5469 -> 0.06665
#     Concept 1831 -> 0.06388
#     Concept 1758 -> 0.05792
#     Concept 2621 -> 0.05568
#     Concept 3304 -> 0.04266
#     Concept 2308 -> 0.03839
#     Concept 3821 -> 0.03769
#     Concept 4955 -> 0.03377
#     Concept 4721 -> 0.03037
#     Concept 5461 -> 0.02883
#     Concept 5832 -> 0.02806
#     Concept 4080 -> 0.02725
#     Concept 1611 -> 0.02703
#     Concept 1001 -> 0.02555
#     Concept 1893 -> 0.02301
#     Concept 5231 -> 0.02087
#     Concept 2647 -> 0.01983
#     Concept 1226 -> 0.01887
#     Concept 3625 -> 0.01620
#     Concept 5660 -> 0.01228
#     Concept 1905 -> 0.01225
#     Concept 4154 -> 0.01221
#     Concept 3715 -> 0.01169
#
# Class 3 ============================================================
# Domain: INET
#     Concept 1001 -> 0.00191
#     Concept 4721 -> 0.00129
#     Concept 1645 -> 0.00015
#     Concept 5636 -> 0.00007
#     Concept 2028 -> -0.00010
#     Concept 2128 -> -0.00009
#     Concept 2581 -> -0.00004
#     Concept 1971 -> -0.00003
# Domain: Sketch
#     Concept 1001 -> 0.00518
#     Concept 4721 -> 0.00433
#     Concept 1971 -> 0.00154
#     Concept 2128 -> 0.00115
#     Concept 1611 -> 0.00052
#     Concept 3304 -> 0.00048
#     Concept 1524 -> 0.00041
# Aggregated
#     Concept 1001 -> 0.87968
#     Concept 4721 -> 0.64754
#     Concept 1971 -> 0.10826
#     Concept 2128 -> 0.10029
#     Concept 1645 -> 0.04438
#     Concept 1611 -> 0.03330
#     Concept 3304 -> 0.03050
#     Concept 2028 -> 0.03020
#     Concept 1524 -> 0.02595
#     Concept 5636 -> 0.01880
#     Concept 2581 -> 0.01226
#
# Class 4 ============================================================
# Domain: INET
#     Concept 5636 -> 0.00231
#     Concept 2128 -> 0.00095
#     Concept 5509 -> 0.00060
#     Concept 1746 -> 0.00024
#     Concept 2581 -> 0.00023
#     Concept 2076 -> 0.00012
#     Concept 2473 -> 0.00012
#     Concept 4721 -> 0.00011
#     Concept 2801 -> 0.00011
#     Concept 3633 -> 0.00010
#     Concept 4761 -> 0.00010
#     Concept 6054 -> 0.00010
#     Concept 4853 -> 0.00007
#     Concept 1971 -> 0.00005
#     Concept 4373 -> 0.00004
#     Concept 802 -> 0.00004
#     Concept 9 -> 0.00004
#     Concept 5127 -> 0.00004
#     Concept 837 -> 0.00004
#     Concept 4000 -> -0.00020
#     Concept 5205 -> -0.00015
#     Concept 5076 -> -0.00015
#     Concept 4989 -> -0.00010
#     Concept 2797 -> -0.00006
#     Concept 3304 -> -0.00006
#     Concept 201 -> -0.00005
#     Concept 2310 -> -0.00004
#     Concept 2224 -> -0.00004
#     Concept 1779 -> -0.00003
# Domain: Sketch
#     Concept 2128 -> 0.01265
#     Concept 5636 -> 0.00443
#     Concept 5461 -> 0.00394
#     Concept 1758 -> 0.00391
#     Concept 5797 -> 0.00340
#     Concept 2998 -> 0.00165
#     Concept 531 -> 0.00143
#     Concept 2621 -> 0.00082
#     Concept 448 -> 0.00068
#     Concept 4955 -> 0.00041
#     Concept 3304 -> -0.00613
#     Concept 5594 -> -0.00235
#     Concept 4721 -> -0.00063
# Aggregated
#     Concept 2128 -> 1.08328
#     Concept 5636 -> 0.94818
#     Concept 3304 -> 0.40872
#     Concept 5461 -> 0.25244
#     Concept 1758 -> 0.25048
#     Concept 5797 -> 0.21748
#     Concept 5509 -> 0.17155
#     Concept 5594 -> 0.15054
#     Concept 2998 -> 0.10566
#     Concept 531 -> 0.09170
#     Concept 4721 -> 0.07305
#     Concept 1746 -> 0.06937
#     Concept 2581 -> 0.06645
#     Concept 4000 -> 0.05838
#     Concept 2621 -> 0.05279
#     Concept 448 -> 0.04381
#     Concept 5205 -> 0.04344
#     Concept 5076 -> 0.04208
#     Concept 2076 -> 0.03399
#     Concept 2473 -> 0.03341
#     Concept 2801 -> 0.03242
#     Concept 4989 -> 0.02994
#     Concept 3633 -> 0.02959
#     Concept 4761 -> 0.02927
#     Concept 6054 -> 0.02821
#     Concept 4955 -> 0.02651
#     Concept 4853 -> 0.02124
#     Concept 2797 -> 0.01791
#     Concept 1971 -> 0.01497
#     Concept 201 -> 0.01301
#     Concept 2310 -> 0.01211
#     Concept 4373 -> 0.01187
#     Concept 2224 -> 0.01155
#     Concept 802 -> 0.01133
#     Concept 9 -> 0.01101
#     Concept 5127 -> 0.01043
#     Concept 837 -> 0.01009
#     Concept 1779 -> 0.00996
#
# Class 5 ============================================================
# Domain: INET
#     Concept 1919 -> 0.00168
#     Concept 2427 -> 0.00100
#     Concept 1002 -> 0.00094
#     Concept 837 -> 0.00066
#     Concept 4761 -> 0.00010
#     Concept 5127 -> 0.00009
#     Concept 764 -> 0.00007
#     Concept 2852 -> 0.00007
#     Concept 938 -> 0.00006
#     Concept 2468 -> 0.00006
#     Concept 4989 -> 0.00005
#     Concept 1555 -> 0.00005
#     Concept 3936 -> -0.00012
#     Concept 3304 -> -0.00005
#     Concept 1543 -> -0.00004
#     Concept 3492 -> -0.00004
# Domain: Sketch
#     Concept 1002 -> 0.00634
#     Concept 2427 -> 0.00532
#     Concept 3767 -> 0.00457
#     Concept 5594 -> 0.00452
#     Concept 5797 -> 0.00331
#     Concept 3394 -> 0.00080
#     Concept 1524 -> 0.00026
#     Concept 1919 -> 0.00024
#     Concept 3304 -> 0.00018
#     Concept 5974 -> -0.00259
#     Concept 2077 -> -0.00188
#     Concept 3639 -> -0.00151
#     Concept 1746 -> -0.00131
#     Concept 1611 -> -0.00112
#     Concept 2621 -> -0.00077
#     Concept 1971 -> -0.00052
# Aggregated
#     Concept 1002 -> 0.67633
#     Concept 2427 -> 0.62890
#     Concept 1919 -> 0.49912
#     Concept 3767 -> 0.29273
#     Concept 5594 -> 0.28916
#     Concept 5797 -> 0.21170
#     Concept 837 -> 0.18960
#     Concept 5974 -> 0.16579
#     Concept 2077 -> 0.12061
#     Concept 3639 -> 0.09679
#     Concept 1746 -> 0.08376
#     Concept 1611 -> 0.07183
#     Concept 3394 -> 0.05123
#     Concept 2621 -> 0.04945
#     Concept 3936 -> 0.03583
#     Concept 1971 -> 0.03351
#     Concept 4761 -> 0.02879
#     Concept 3304 -> 0.02661
#     Concept 5127 -> 0.02638
#     Concept 764 -> 0.01967
#     Concept 2852 -> 0.01943
#     Concept 938 -> 0.01766
#     Concept 2468 -> 0.01659
#     Concept 1524 -> 0.01638
#     Concept 4989 -> 0.01499
#     Concept 1555 -> 0.01467
#     Concept 1543 -> 0.01162
#     Concept 3492 -> 0.01083
#
# Class 6 ============================================================
# Domain: INET
#     Concept 2427 -> 0.00196
#     Concept 1002 -> 0.00130
#     Concept 3936 -> 0.00026
#     Concept 938 -> 0.00015
#     Concept 1654 -> 0.00014
#     Concept 424 -> 0.00013
#     Concept 3492 -> 0.00009
#     Concept 201 -> 0.00008
#     Concept 2468 -> 0.00007
#     Concept 5411 -> 0.00006
#     Concept 1971 -> 0.00006
#     Concept 3346 -> 0.00006
#     Concept 3470 -> 0.00005
#     Concept 4000 -> 0.00005
#     Concept 5509 -> 0.00005
#     Concept 2852 -> -0.00007
# Domain: Sketch
#     Concept 3304 -> 0.00276
#     Concept 1971 -> 0.00065
#     Concept 4955 -> 0.00062
#     Concept 1758 -> 0.00014
# Aggregated
#     Concept 2427 -> 0.56273
#     Concept 1002 -> 0.37408
#     Concept 3304 -> 0.17678
#     Concept 3936 -> 0.07357
#     Concept 1971 -> 0.05966
#     Concept 938 -> 0.04215
#     Concept 4955 -> 0.03988
#     Concept 1654 -> 0.03932
#     Concept 424 -> 0.03857
#     Concept 3492 -> 0.02711
#     Concept 201 -> 0.02359
#     Concept 2468 -> 0.01884
#     Concept 2852 -> 0.01881
#     Concept 5411 -> 0.01833
#     Concept 3346 -> 0.01782
#     Concept 3470 -> 0.01491
#     Concept 4000 -> 0.01470
#     Concept 5509 -> 0.01332
#     Concept 1758 -> 0.00878
#
# Class 7 ============================================================
# Domain: INET
#     Concept 3985 -> 0.00168
#     Concept 4783 -> 0.00167
#     Concept 854 -> 0.00025
#     Concept 2646 -> 0.00012
#     Concept 1175 -> 0.00008
#     Concept 4017 -> 0.00005
#     Concept 2537 -> 0.00005
#     Concept 3304 -> 0.00004
#     Concept 1543 -> -0.00006
#     Concept 1835 -> -0.00005
#     Concept 3227 -> -0.00005
#     Concept 3853 -> -0.00004
#     Concept 2605 -> -0.00004
#     Concept 1971 -> -0.00004
#     Concept 5737 -> -0.00004
# Domain: Sketch
#     Concept 4783 -> 0.00768
#     Concept 3985 -> 0.00641
#     Concept 1971 -> 0.00301
#     Concept 5594 -> 0.00198
#     Concept 4017 -> 0.00194
#     Concept 1543 -> -0.00349
#     Concept 2077 -> -0.00278
#     Concept 1611 -> -0.00190
#     Concept 2614 -> -0.00031
# Aggregated
#     Concept 4783 -> 0.97181
#     Concept 3985 -> 0.89441
#     Concept 1543 -> 0.24024
#     Concept 1971 -> 0.20375
#     Concept 2077 -> 0.17809
#     Concept 4017 -> 0.13902
#     Concept 5594 -> 0.12681
#     Concept 1611 -> 0.12182
#     Concept 854 -> 0.07276
#     Concept 2646 -> 0.03557
#     Concept 1175 -> 0.02438
#     Concept 2614 -> 0.02016
#     Concept 1835 -> 0.01354
#     Concept 2537 -> 0.01333
#     Concept 3227 -> 0.01318
#     Concept 3853 -> 0.01272
#     Concept 2605 -> 0.01159
#     Concept 5737 -> 0.01132
#     Concept 3304 -> 0.01091
#
# Class 8 ============================================================
# Domain: INET
#     Concept 1835 -> 0.00225
#     Concept 4017 -> 0.00123
#     Concept 3853 -> 0.00005
#     Concept 4783 -> 0.00005
#     Concept 3227 -> 0.00005
#     Concept 706 -> 0.00005
#     Concept 5737 -> 0.00004
#     Concept 2605 -> 0.00004
#     Concept 1543 -> 0.00004
#     Concept 5724 -> 0.00004
#     Concept 4523 -> 0.00004
# Domain: Sketch
#     Concept 3985 -> 0.00655
#     Concept 1835 -> 0.00329
#     Concept 3304 -> 0.00274
#     Concept 4017 -> 0.00223
#     Concept 349 -> 0.00204
#     Concept 4783 -> 0.00178
#     Concept 2808 -> 0.00105
#     Concept 5797 -> 0.00091
#     Concept 1971 -> 0.00084
#     Concept 5594 -> 0.00035
# Aggregated
#     Concept 1835 -> 0.85675
#     Concept 4017 -> 0.49773
#     Concept 3985 -> 0.41946
#     Concept 3304 -> 0.17536
#     Concept 349 -> 0.13081
#     Concept 4783 -> 0.12846
#     Concept 2808 -> 0.06691
#     Concept 5797 -> 0.05851
#     Concept 1971 -> 0.05390
#     Concept 5594 -> 0.02265
#     Concept 3853 -> 0.01566
#     Concept 3227 -> 0.01431
#     Concept 706 -> 0.01300
#     Concept 5737 -> 0.01263
#     Concept 2605 -> 0.01169
#     Concept 1543 -> 0.01146
#     Concept 5724 -> 0.01027
#     Concept 4523 -> 0.01020
#
# Class 9 ============================================================
# Domain: INET
#     Concept 2348 -> 0.00148
#     Concept 2043 -> 0.00126
#     Concept 3218 -> 0.00009
#     Concept 1758 -> 0.00007
#     Concept 3843 -> 0.00006
#     Concept 2087 -> 0.00004
#     Concept 3304 -> 0.00004
#     Concept 1555 -> 0.00003
# Domain: Sketch
# Aggregated
#     Concept 2348 -> 0.42487
#     Concept 2043 -> 0.36288
#     Concept 3218 -> 0.02510
#     Concept 1758 -> 0.02029
#     Concept 3843 -> 0.01840
#     Concept 2087 -> 0.01230
#     Concept 3304 -> 0.01115
#     Concept 1555 -> 0.00993
#
# Class 10 ============================================================
# Domain: INET
#     Concept 637 -> 0.00161
#     Concept 863 -> 0.00139
#     Concept 1979 -> 0.00019
#     Concept 2505 -> 0.00010
#     Concept 1543 -> 0.00010
#     Concept 1354 -> 0.00008
#     Concept 5428 -> 0.00007
#     Concept 2158 -> 0.00007
#     Concept 3304 -> 0.00006
#     Concept 2139 -> 0.00006
#     Concept 2504 -> 0.00005
#     Concept 191 -> 0.00005
#     Concept 1502 -> 0.00005
#     Concept 4670 -> 0.00004
#     Concept 2064 -> 0.00003
# Domain: Sketch
#     Concept 3304 -> 0.00214
#     Concept 637 -> 0.00201
#     Concept 1971 -> 0.00137
#     Concept 5594 -> 0.00116
# Aggregated
#     Concept 637 -> 0.59271
#     Concept 863 -> 0.39871
#     Concept 3304 -> 0.15539
#     Concept 1971 -> 0.08784
#     Concept 5594 -> 0.07455
#     Concept 1979 -> 0.05408
#     Concept 2505 -> 0.02822
#     Concept 1543 -> 0.02772
#     Concept 1354 -> 0.02206
#     Concept 5428 -> 0.02098
#     Concept 2158 -> 0.02093
#     Concept 2139 -> 0.01600
#     Concept 2504 -> 0.01480
#     Concept 191 -> 0.01440
#     Concept 1502 -> 0.01322
#     Concept 4670 -> 0.01022
#     Concept 2064 -> 0.00986
#
# Class 11 ============================================================
# Domain: INET
#     Concept 3839 -> 0.00274
#     Concept 5663 -> 0.00007
#     Concept 2922 -> 0.00007
# Domain: Sketch
#     Concept 3839 -> 0.00826
#     Concept 2310 -> 0.00184
#     Concept 1971 -> 0.00174
#     Concept 2922 -> 0.00133
#     Concept 2874 -> 0.00089
#     Concept 1611 -> 0.00088
#     Concept 2614 -> 0.00087
#     Concept 5994 -> 0.00078
#     Concept 3979 -> 0.00068
#     Concept 549 -> 0.00026
#     Concept 5594 -> -0.00136
# Aggregated
#     Concept 3839 -> 1.31790
#     Concept 2310 -> 0.11773
#     Concept 1971 -> 0.11153
#     Concept 2922 -> 0.10638
#     Concept 5594 -> 0.08700
#     Concept 2874 -> 0.05705
#     Concept 1611 -> 0.05655
#     Concept 2614 -> 0.05595
#     Concept 5994 -> 0.05016
#     Concept 3979 -> 0.04329
#     Concept 5663 -> 0.02142
#     Concept 549 -> 0.01685
#
# Class 12 ============================================================
# Domain: INET
#     Concept 1502 -> 0.00299
#     Concept 529 -> 0.00043
#     Concept 1367 -> 0.00021
#     Concept 3304 -> 0.00003
#     Concept 1543 -> -0.00006
# Domain: Sketch
#     Concept 1502 -> 0.00772
#     Concept 1971 -> 0.00228
#     Concept 1758 -> 0.00193
#     Concept 5594 -> -0.00019
# Aggregated
#     Concept 1502 -> 1.35442
#     Concept 1971 -> 0.14584
#     Concept 1758 -> 0.12351
#     Concept 529 -> 0.12334
#     Concept 1367 -> 0.05940
#     Concept 1543 -> 0.01843
#     Concept 5594 -> 0.01223
#     Concept 3304 -> 0.00979
#
# Class 13 ============================================================
# Domain: INET
#     Concept 5676 -> 0.00239
#     Concept 6024 -> 0.00066
# Domain: Sketch
#     Concept 5676 -> 0.00793
#     Concept 6024 -> 0.00447
#     Concept 2505 -> 0.00398
#     Concept 2614 -> 0.00239
#     Concept 1543 -> 0.00183
#     Concept 2310 -> 0.00156
#     Concept 2621 -> 0.00106
#     Concept 4955 -> 0.00084
#     Concept 1971 -> 0.00067
#     Concept 483 -> 0.00024
# Aggregated
#     Concept 5676 -> 1.19558
#     Concept 6024 -> 0.47590
#     Concept 2505 -> 0.25508
#     Concept 2614 -> 0.15273
#     Concept 1543 -> 0.11742
#     Concept 2310 -> 0.10014
#     Concept 2621 -> 0.06771
#     Concept 4955 -> 0.05407
#     Concept 1971 -> 0.04269
#     Concept 483 -> 0.01567
#
# Class 14 ============================================================
# Domain: INET
#     Concept 2808 -> 0.00180
#     Concept 349 -> 0.00127
#     Concept 1784 -> 0.00008
# Domain: Sketch
#     Concept 1783 -> 0.00798
#     Concept 2808 -> 0.00542
#     Concept 349 -> 0.00375
#     Concept 5994 -> 0.00310
#     Concept 1971 -> 0.00303
#     Concept 1502 -> 0.00188
#     Concept 4955 -> 0.00181
#     Concept 2614 -> 0.00172
#     Concept 5594 -> 0.00153
#     Concept 3504 -> 0.00110
#     Concept 4984 -> 0.00085
#     Concept 1758 -> 0.00044
#     Concept 3839 -> 0.00034
#     Concept 1784 -> 0.00022
#     Concept 1611 -> -0.00162
#     Concept 854 -> -0.00081
#     Concept 3304 -> -0.00057
#     Concept 579 -> -0.00037
# Aggregated
#     Concept 2808 -> 0.86588
#     Concept 349 -> 0.60419
#     Concept 1783 -> 0.51066
#     Concept 5994 -> 0.19834
#     Concept 1971 -> 0.19404
#     Concept 1502 -> 0.12028
#     Concept 4955 -> 0.11567
#     Concept 2614 -> 0.11027
#     Concept 1611 -> 0.10353
#     Concept 5594 -> 0.09825
#     Concept 3504 -> 0.07029
#     Concept 4984 -> 0.05471
#     Concept 854 -> 0.05178
#     Concept 1784 -> 0.03832
#     Concept 3304 -> 0.03643
#     Concept 1758 -> 0.02814
#     Concept 579 -> 0.02371
#     Concept 3839 -> 0.02145
#
# Class 15 ============================================================
# Domain: INET
#     Concept 3979 -> 0.00318
#     Concept 367 -> 0.00046
#     Concept 1453 -> 0.00026
#     Concept 1477 -> 0.00014
#     Concept 4453 -> 0.00012
#     Concept 132 -> 0.00008
#     Concept 2264 -> -0.00032
#     Concept 4201 -> -0.00022
#     Concept 4323 -> -0.00012
#     Concept 1543 -> -0.00006
# Domain: Sketch
#     Concept 3979 -> 0.00727
#     Concept 5495 -> 0.00641
#     Concept 4984 -> 0.00475
#     Concept 4955 -> 0.00440
#     Concept 44 -> 0.00383
#     Concept 1746 -> 0.00360
#     Concept 2640 -> 0.00342
#     Concept 4067 -> 0.00301
#     Concept 5594 -> 0.00294
#     Concept 1971 -> 0.00291
#     Concept 1758 -> 0.00169
#     Concept 2505 -> 0.00160
#     Concept 2614 -> 0.00156
#     Concept 3401 -> 0.00114
#     Concept 483 -> 0.00066
#     Concept 2647 -> 0.00064
#     Concept 2262 -> 0.00061
#     Concept 3963 -> 0.00057
#     Concept 878 -> 0.00048
#     Concept 1641 -> 0.00045
#     Concept 960 -> 0.00038
#     Concept 3821 -> 0.00035
#     Concept 4017 -> 0.00019
#     Concept 3304 -> -0.00278
#     Concept 3839 -> -0.00263
#     Concept 1317 -> -0.00244
#     Concept 135 -> -0.00232
#     Concept 1611 -> -0.00211
#     Concept 132 -> -0.00207
#     Concept 5994 -> -0.00184
#     Concept 5357 -> -0.00166
#     Concept 2621 -> -0.00145
#     Concept 5797 -> -0.00110
#     Concept 6085 -> -0.00068
#     Concept 1555 -> -0.00060
#     Concept 5472 -> -0.00048
#     Concept 1524 -> -0.00037
#     Concept 2077 -> -0.00032
#     Concept 4373 -> -0.00027
#     Concept 3639 -> -0.00025
#     Concept 854 -> -0.00021
#     Concept 5721 -> -0.00015
# Aggregated
#     Concept 3979 -> 1.38115
#     Concept 5495 -> 0.41053
#     Concept 4984 -> 0.30420
#     Concept 4955 -> 0.28190
#     Concept 44 -> 0.24529
#     Concept 1746 -> 0.23032
#     Concept 2640 -> 0.21898
#     Concept 4067 -> 0.19295
#     Concept 5594 -> 0.18845
#     Concept 1971 -> 0.18619
#     Concept 3304 -> 0.17786
#     Concept 3839 -> 0.16811
#     Concept 1317 -> 0.15631
#     Concept 132 -> 0.15413
#     Concept 135 -> 0.14856
#     Concept 1611 -> 0.13476
#     Concept 367 -> 0.13126
#     Concept 5994 -> 0.11771
#     Concept 1758 -> 0.10798
#     Concept 5357 -> 0.10621
#     Concept 2505 -> 0.10239
#     Concept 2614 -> 0.10013
#     Concept 2621 -> 0.09273
#     Concept 2264 -> 0.09219
#     Concept 1453 -> 0.07507
#     Concept 3401 -> 0.07326
#     Concept 5797 -> 0.07073
#     Concept 4201 -> 0.06462
#     Concept 6085 -> 0.04369
#     Concept 483 -> 0.04202
#     Concept 2647 -> 0.04076
#     Concept 1477 -> 0.04009
#     Concept 2262 -> 0.03924
#     Concept 1555 -> 0.03817
#     Concept 3963 -> 0.03628
#     Concept 4323 -> 0.03512
#     Concept 4453 -> 0.03393
#     Concept 5472 -> 0.03089
#     Concept 878 -> 0.03055
#     Concept 1641 -> 0.02864
#     Concept 960 -> 0.02459
#     Concept 1524 -> 0.02358
#     Concept 3821 -> 0.02213
#     Concept 2077 -> 0.02030
#     Concept 4373 -> 0.01700
#     Concept 1543 -> 0.01598
#     Concept 3639 -> 0.01584
#     Concept 854 -> 0.01318
#     Concept 4017 -> 0.01210
#     Concept 5721 -> 0.00986
#
# Class 16 ============================================================
# Domain: INET
#     Concept 44 -> 0.00187
#     Concept 132 -> 0.00142
#     Concept 4323 -> 0.00011
#     Concept 5982 -> 0.00006
#     Concept 1453 -> 0.00005
#     Concept 5495 -> 0.00005
#     Concept 5973 -> 0.00005
#     Concept 4727 -> 0.00004
#     Concept 3979 -> 0.00004
#     Concept 4453 -> 0.00004
#     Concept 4851 -> 0.00004
#     Concept 5884 -> 0.00004
#     Concept 4017 -> 0.00004
#     Concept 3603 -> 0.00004
#     Concept 1477 -> -0.00007
# Domain: Sketch
#     Concept 44 -> 0.00447
#     Concept 132 -> 0.00408
#     Concept 1611 -> 0.00188
#     Concept 5405 -> 0.00153
#     Concept 1971 -> 0.00116
#     Concept 3304 -> 0.00100
#     Concept 3821 -> 0.00086
#     Concept 1798 -> 0.00085
#     Concept 5495 -> 0.00034
#     Concept 5594 -> 0.00030
#     Concept 5973 -> 0.00013
# Aggregated
#     Concept 44 -> 0.82413
#     Concept 132 -> 0.66995
#     Concept 1611 -> 0.12027
#     Concept 5405 -> 0.09818
#     Concept 1971 -> 0.07399
#     Concept 3304 -> 0.06422
#     Concept 3821 -> 0.05523
#     Concept 1798 -> 0.05426
#     Concept 5495 -> 0.03596
#     Concept 4323 -> 0.03062
#     Concept 5973 -> 0.02202
#     Concept 1477 -> 0.02121
#     Concept 5594 -> 0.01908
#     Concept 5982 -> 0.01603
#     Concept 1453 -> 0.01566
#     Concept 4727 -> 0.01213
#     Concept 3979 -> 0.01158
#     Concept 4453 -> 0.01057
#     Concept 4851 -> 0.01039
#     Concept 5884 -> 0.01036
#     Concept 4017 -> 0.01028
#     Concept 3603 -> 0.01023
#
# Class 17 ============================================================
# Domain: INET
#     Concept 1100 -> 0.00181
#     Concept 4201 -> 0.00145
#     Concept 2264 -> 0.00033
#     Concept 5005 -> 0.00028
#     Concept 3979 -> 0.00015
#     Concept 3205 -> 0.00009
#     Concept 4017 -> 0.00007
#     Concept 3186 -> 0.00004
#     Concept 3547 -> 0.00004
#     Concept 4697 -> 0.00004
#     Concept 1125 -> 0.00004
#     Concept 1543 -> -0.00004
# Domain: Sketch
#     Concept 4201 -> 0.01001
#     Concept 1100 -> 0.00533
#     Concept 1971 -> 0.00291
#     Concept 5594 -> 0.00242
#     Concept 854 -> 0.00217
#     Concept 4154 -> 0.00116
#     Concept 5123 -> 0.00067
#     Concept 2614 -> 0.00061
#     Concept 3304 -> 0.00050
#     Concept 1611 -> -0.00242
#     Concept 1317 -> -0.00146
#     Concept 210 -> -0.00121
#     Concept 2077 -> -0.00110
#     Concept 2310 -> -0.00052
# Aggregated
#     Concept 4201 -> 1.05923
#     Concept 1100 -> 0.86215
#     Concept 1971 -> 0.18612
#     Concept 5594 -> 0.15513
#     Concept 1611 -> 0.15506
#     Concept 854 -> 0.13893
#     Concept 2264 -> 0.09608
#     Concept 1317 -> 0.09347
#     Concept 5005 -> 0.08034
#     Concept 210 -> 0.07763
#     Concept 4154 -> 0.07431
#     Concept 2077 -> 0.07052
#     Concept 5123 -> 0.04290
#     Concept 3979 -> 0.04228
#     Concept 2614 -> 0.03882
#     Concept 2310 -> 0.03353
#     Concept 3304 -> 0.03216
#     Concept 3205 -> 0.02669
#     Concept 4017 -> 0.02122
#     Concept 3186 -> 0.01213
#     Concept 3547 -> 0.01200
#     Concept 4697 -> 0.01116
#     Concept 1125 -> 0.01023
#     Concept 1543 -> 0.01018
#
# Class 18 ============================================================
# Domain: INET
#     Concept 4409 -> 0.00319
#     Concept 352 -> 0.00058
#     Concept 3304 -> 0.00019
#     Concept 1072 -> 0.00017
#     Concept 2139 -> 0.00017
#     Concept 354 -> 0.00017
#     Concept 3296 -> 0.00012
#     Concept 1543 -> 0.00011
#     Concept 1650 -> 0.00011
#     Concept 4217 -> 0.00011
#     Concept 2824 -> 0.00011
#     Concept 1037 -> 0.00010
#     Concept 353 -> 0.00010
#     Concept 2557 -> 0.00010
#     Concept 661 -> 0.00008
#     Concept 4329 -> 0.00008
#     Concept 6039 -> 0.00006
#     Concept 4653 -> 0.00006
#     Concept 5239 -> 0.00006
#     Concept 5074 -> 0.00005
#     Concept 4391 -> 0.00005
#     Concept 5667 -> 0.00005
#     Concept 4373 -> 0.00005
#     Concept 2597 -> 0.00004
#     Concept 3271 -> 0.00004
#     Concept 5638 -> 0.00004
# Domain: Sketch
#     Concept 1037 -> 0.00749
#     Concept 4409 -> 0.00516
#     Concept 1575 -> 0.00459
#     Concept 5049 -> 0.00442
#     Concept 1971 -> 0.00254
#     Concept 3271 -> 0.00185
#     Concept 2621 -> 0.00143
#     Concept 573 -> 0.00104
#     Concept 4358 -> 0.00085
#     Concept 352 -> 0.00037
#     Concept 1543 -> -0.00244
#     Concept 5594 -> -0.00150
#     Concept 210 -> -0.00098
#     Concept 3963 -> -0.00052
#     Concept 2006 -> -0.00039
#     Concept 1945 -> -0.00022
# Aggregated
#     Concept 4409 -> 1.24775
#     Concept 1037 -> 0.50859
#     Concept 1575 -> 0.29390
#     Concept 5049 -> 0.28321
#     Concept 352 -> 0.19172
#     Concept 1543 -> 0.18851
#     Concept 1971 -> 0.16259
#     Concept 3271 -> 0.13044
#     Concept 5594 -> 0.09575
#     Concept 2621 -> 0.09138
#     Concept 573 -> 0.06675
#     Concept 210 -> 0.06261
#     Concept 3304 -> 0.05610
#     Concept 4358 -> 0.05422
#     Concept 1072 -> 0.04899
#     Concept 2139 -> 0.04818
#     Concept 354 -> 0.04784
#     Concept 3296 -> 0.03577
#     Concept 3963 -> 0.03348
#     Concept 1650 -> 0.03183
#     Concept 4217 -> 0.03116
#     Concept 2824 -> 0.03074
#     Concept 353 -> 0.02871
#     Concept 2557 -> 0.02799
#     Concept 2006 -> 0.02517
#     Concept 661 -> 0.02189
#     Concept 4329 -> 0.02184
#     Concept 6039 -> 0.01861
#     Concept 4653 -> 0.01748
#     Concept 5239 -> 0.01729
#     Concept 5074 -> 0.01511
#     Concept 4391 -> 0.01452
#     Concept 1945 -> 0.01423
#     Concept 5667 -> 0.01416
#     Concept 4373 -> 0.01323
#     Concept 2597 -> 0.01284
#     Concept 5638 -> 0.01148
#
# Class 19 ============================================================
# Domain: INET
#     Concept 352 -> 0.00224
#     Concept 4391 -> 0.00072
#     Concept 1543 -> -0.00008
#     Concept 6039 -> -0.00007
#     Concept 1072 -> -0.00005
#     Concept 5239 -> -0.00005
#     Concept 3296 -> -0.00004
#     Concept 2824 -> -0.00004
# Domain: Sketch
#     Concept 1537 -> 0.00300
#     Concept 352 -> 0.00274
#     Concept 4391 -> 0.00210
#     Concept 5797 -> 0.00185
#     Concept 5594 -> 0.00163
#     Concept 1575 -> 0.00116
#     Concept 3304 -> 0.00061
#     Concept 1971 -> 0.00050
#     Concept 1162 -> 0.00027
# Aggregated
#     Concept 352 -> 0.82156
#     Concept 4391 -> 0.34077
#     Concept 1537 -> 0.19222
#     Concept 5797 -> 0.11869
#     Concept 5594 -> 0.10423
#     Concept 1575 -> 0.07425
#     Concept 3304 -> 0.03915
#     Concept 1971 -> 0.03177
#     Concept 1543 -> 0.02267
#     Concept 6039 -> 0.01883
#     Concept 1162 -> 0.01709
#     Concept 1072 -> 0.01528
#     Concept 5239 -> 0.01421
#     Concept 3296 -> 0.01074
#     Concept 2824 -> 0.01033
#
# Class 20 ============================================================
# Domain: INET
#     Concept 6039 -> 0.00164
#     Concept 5239 -> 0.00123
#     Concept 1666 -> 0.00005
#     Concept 1555 -> 0.00004
# Domain: Sketch
#     Concept 6039 -> 0.00521
#     Concept 1971 -> 0.00171
#     Concept 4458 -> 0.00127
#     Concept 5239 -> 0.00099
#     Concept 1611 -> 0.00054
# Aggregated
#     Concept 6039 -> 0.80567
#     Concept 5239 -> 0.41814
#     Concept 1971 -> 0.10928
#     Concept 4458 -> 0.08112
#     Concept 1611 -> 0.03462
#     Concept 1666 -> 0.01549
#     Concept 1555 -> 0.01159
#
# Class 21 ============================================================
# Domain: INET
#     Concept 4954 -> 0.00348
#     Concept 4833 -> 0.00025
#     Concept 473 -> 0.00013
#     Concept 1971 -> 0.00013
#     Concept 3542 -> 0.00005
#     Concept 2791 -> 0.00003
# Domain: Sketch
#     Concept 4954 -> 0.00587
#     Concept 4749 -> 0.00291
#     Concept 473 -> 0.00231
#     Concept 5797 -> 0.00225
#     Concept 2621 -> 0.00196
#     Concept 3304 -> 0.00135
#     Concept 1555 -> 0.00125
#     Concept 1971 -> 0.00120
#     Concept 1524 -> 0.00108
#     Concept 5594 -> -0.00240
# Aggregated
#     Concept 4954 -> 1.37579
#     Concept 4749 -> 0.18615
#     Concept 473 -> 0.18516
#     Concept 5594 -> 0.15341
#     Concept 5797 -> 0.14422
#     Concept 2621 -> 0.12528
#     Concept 1971 -> 0.11305
#     Concept 3304 -> 0.08631
#     Concept 1555 -> 0.08011
#     Concept 4833 -> 0.07128
#     Concept 1524 -> 0.06886
#     Concept 3542 -> 0.01363
#     Concept 2791 -> 0.01004
#
# Class 22 ============================================================
# Domain: INET
#     Concept 323 -> 0.00203
#     Concept 97 -> 0.00064
#     Concept 1347 -> 0.00012
#     Concept 3439 -> 0.00004
#     Concept 4989 -> -0.00011
#     Concept 4083 -> -0.00011
#     Concept 1971 -> -0.00009
#     Concept 802 -> -0.00007
#     Concept 4761 -> -0.00007
#     Concept 3304 -> -0.00007
#     Concept 4588 -> -0.00007
#     Concept 4853 -> -0.00006
#     Concept 4317 -> -0.00005
#     Concept 5234 -> -0.00004
#     Concept 784 -> -0.00004
#     Concept 4655 -> -0.00004
#     Concept 1363 -> -0.00004
#     Concept 243 -> -0.00003
# Domain: Sketch
#     Concept 323 -> 0.00512
#     Concept 97 -> 0.00405
#     Concept 1971 -> 0.00400
#     Concept 5594 -> 0.00272
#     Concept 1543 -> -0.00404
#     Concept 3304 -> -0.00326
#     Concept 1611 -> -0.00262
#     Concept 1555 -> -0.00043
#     Concept 1317 -> -0.00020
# Aggregated
#     Concept 323 -> 0.91124
#     Concept 97 -> 0.44263
#     Concept 1971 -> 0.28201
#     Concept 1543 -> 0.25831
#     Concept 3304 -> 0.22749
#     Concept 5594 -> 0.17411
#     Concept 1611 -> 0.16794
#     Concept 1347 -> 0.03366
#     Concept 4989 -> 0.03150
#     Concept 4083 -> 0.03131
#     Concept 1555 -> 0.02781
#     Concept 802 -> 0.02134
#     Concept 4761 -> 0.01968
#     Concept 4588 -> 0.01876
#     Concept 4853 -> 0.01783
#     Concept 4317 -> 0.01362
#     Concept 1317 -> 0.01309
#     Concept 5234 -> 0.01281
#     Concept 784 -> 0.01251
#     Concept 4655 -> 0.01238
#     Concept 3439 -> 0.01165
#     Concept 1363 -> 0.01015
#     Concept 243 -> 0.01000
#
# Class 23 ============================================================
# Domain: INET
#     Concept 1511 -> 0.00184
#     Concept 5868 -> 0.00180
#     Concept 323 -> 0.00040
#     Concept 4989 -> 0.00024
#     Concept 4761 -> 0.00018
#     Concept 549 -> 0.00018
#     Concept 4853 -> 0.00017
#     Concept 4083 -> 0.00016
#     Concept 2666 -> 0.00012
#     Concept 4655 -> 0.00012
#     Concept 1363 -> 0.00012
#     Concept 97 -> 0.00011
#     Concept 1347 -> 0.00011
#     Concept 5721 -> 0.00010
#     Concept 5127 -> 0.00010
#     Concept 2049 -> 0.00009
#     Concept 3633 -> 0.00009
#     Concept 4571 -> 0.00008
#     Concept 4317 -> 0.00007
#     Concept 3304 -> 0.00006
#     Concept 243 -> 0.00006
#     Concept 802 -> 0.00006
#     Concept 201 -> 0.00005
#     Concept 1971 -> 0.00005
#     Concept 1543 -> 0.00005
#     Concept 4766 -> 0.00005
#     Concept 4373 -> 0.00005
#     Concept 5234 -> 0.00005
#     Concept 5250 -> 0.00004
#     Concept 2576 -> 0.00004
#     Concept 2360 -> 0.00004
#     Concept 4588 -> 0.00004
#     Concept 2621 -> 0.00004
#     Concept 1705 -> 0.00004
#     Concept 5884 -> 0.00004
#     Concept 1947 -> 0.00004
#     Concept 4080 -> 0.00004
#     Concept 3227 -> 0.00004
#     Concept 784 -> 0.00003
# Domain: Sketch
#     Concept 2666 -> 0.00683
#     Concept 1511 -> 0.00530
#     Concept 5868 -> 0.00461
#     Concept 2717 -> 0.00428
#     Concept 1543 -> 0.00304
#     Concept 1971 -> 0.00300
#     Concept 4955 -> 0.00261
#     Concept 1555 -> 0.00245
#     Concept 3652 -> 0.00232
#     Concept 323 -> 0.00214
#     Concept 5797 -> 0.00189
#     Concept 2484 -> 0.00157
#     Concept 1758 -> 0.00078
#     Concept 2077 -> 0.00074
#     Concept 97 -> 0.00066
#     Concept 3963 -> 0.00065
#     Concept 1947 -> 0.00023
#     Concept 4967 -> -0.00370
#     Concept 3304 -> -0.00238
#     Concept 5594 -> -0.00225
#     Concept 1611 -> -0.00073
#     Concept 1524 -> -0.00049
#     Concept 2621 -> -0.00040
#     Concept 483 -> -0.00026
# Aggregated
#     Concept 1511 -> 0.86778
#     Concept 5868 -> 0.81402
#     Concept 2666 -> 0.47248
#     Concept 2717 -> 0.27410
#     Concept 323 -> 0.25273
#     Concept 4967 -> 0.23699
#     Concept 1543 -> 0.21001
#     Concept 1971 -> 0.20761
#     Concept 3304 -> 0.17073
#     Concept 4955 -> 0.16720
#     Concept 1555 -> 0.15702
#     Concept 3652 -> 0.14851
#     Concept 5594 -> 0.14391
#     Concept 5797 -> 0.12111
#     Concept 2484 -> 0.10033
#     Concept 97 -> 0.07370
#     Concept 4989 -> 0.06906
#     Concept 4761 -> 0.05150
#     Concept 549 -> 0.05127
#     Concept 1758 -> 0.05012
#     Concept 4853 -> 0.04917
#     Concept 2077 -> 0.04751
#     Concept 1611 -> 0.04664
#     Concept 4083 -> 0.04650
#     Concept 3963 -> 0.04131
#     Concept 2621 -> 0.03686
#     Concept 4655 -> 0.03419
#     Concept 1363 -> 0.03416
#     Concept 1347 -> 0.03118
#     Concept 1524 -> 0.03108
#     Concept 5721 -> 0.02919
#     Concept 5127 -> 0.02801
#     Concept 2049 -> 0.02588
#     Concept 1947 -> 0.02523
#     Concept 3633 -> 0.02506
#     Concept 4571 -> 0.02224
#     Concept 4317 -> 0.01885
#     Concept 243 -> 0.01714
#     Concept 802 -> 0.01662
#     Concept 483 -> 0.01660
#     Concept 201 -> 0.01578
#     Concept 4766 -> 0.01507
#     Concept 4373 -> 0.01494
#     Concept 5234 -> 0.01408
#     Concept 5250 -> 0.01242
#     Concept 2576 -> 0.01168
#     Concept 2360 -> 0.01109
#     Concept 4588 -> 0.01101
#     Concept 1705 -> 0.01077
#     Concept 5884 -> 0.01037
#     Concept 4080 -> 0.01026
#     Concept 3227 -> 0.01018
#     Concept 784 -> 0.00958
#
# Class 24 ============================================================
# Domain: INET
#     Concept 1498 -> 0.00318
#     Concept 549 -> 0.00104
#     Concept 4098 -> 0.00013
#     Concept 1368 -> 0.00008
#     Concept 1947 -> -0.00007
#     Concept 3304 -> -0.00006
#     Concept 1971 -> -0.00005
#     Concept 1543 -> -0.00005
#     Concept 3680 -> -0.00004
#     Concept 106 -> -0.00003
# Domain: Sketch
#     Concept 1498 -> 0.01362
#     Concept 3304 -> 0.00300
#     Concept 5797 -> 0.00222
#     Concept 4208 -> 0.00135
#     Concept 1611 -> 0.00126
#     Concept 2360 -> 0.00108
#     Concept 4614 -> 0.00072
#     Concept 4098 -> 0.00024
#     Concept 3639 -> -0.00569
#     Concept 1543 -> -0.00519
#     Concept 5594 -> -0.00028
# Aggregated
#     Concept 1498 -> 1.78809
#     Concept 3639 -> 0.36433
#     Concept 1543 -> 0.34552
#     Concept 549 -> 0.29801
#     Concept 3304 -> 0.21034
#     Concept 5797 -> 0.14238
#     Concept 4208 -> 0.08613
#     Concept 1611 -> 0.08062
#     Concept 2360 -> 0.06913
#     Concept 4098 -> 0.05347
#     Concept 4614 -> 0.04636
#     Concept 1368 -> 0.02306
#     Concept 1947 -> 0.02084
#     Concept 5594 -> 0.01783
#     Concept 1971 -> 0.01379
#     Concept 3680 -> 0.01139
#     Concept 106 -> 0.00960
#
# Class 25 ============================================================
# Domain: INET
#     Concept 549 -> 0.00230
#     Concept 2360 -> 0.00112
#     Concept 4098 -> 0.00006
#     Concept 4208 -> 0.00006
#     Concept 1947 -> 0.00005
#     Concept 4373 -> 0.00005
#     Concept 2537 -> 0.00005
#     Concept 106 -> 0.00004
#     Concept 5115 -> 0.00004
#     Concept 1971 -> 0.00004
#     Concept 519 -> -0.00004
# Domain: Sketch
#     Concept 549 -> 0.00254
#     Concept 1971 -> 0.00216
#     Concept 2360 -> 0.00165
#     Concept 3304 -> 0.00138
#     Concept 1555 -> 0.00099
#     Concept 1947 -> 0.00044
# Aggregated
#     Concept 549 -> 0.82466
#     Concept 2360 -> 0.42700
#     Concept 1971 -> 0.14842
#     Concept 3304 -> 0.08846
#     Concept 1555 -> 0.06327
#     Concept 1947 -> 0.04372
#     Concept 4098 -> 0.01727
#     Concept 4208 -> 0.01672
#     Concept 4373 -> 0.01477
#     Concept 2537 -> 0.01411
#     Concept 519 -> 0.01289
#     Concept 106 -> 0.01197
#     Concept 5115 -> 0.01046
#
# Class 26 ============================================================
# Domain: INET
#     Concept 573 -> 0.00292
#     Concept 2887 -> 0.00061
#     Concept 1543 -> 0.00008
#     Concept 4373 -> 0.00007
#     Concept 3304 -> 0.00007
#     Concept 2051 -> 0.00005
# Domain: Sketch
#     Concept 573 -> 0.00869
#     Concept 2887 -> 0.00549
#     Concept 1428 -> 0.00421
#     Concept 5797 -> 0.00264
#     Concept 1037 -> 0.00248
#     Concept 3271 -> 0.00247
#     Concept 1611 -> 0.00165
#     Concept 210 -> 0.00164
#     Concept 1317 -> 0.00143
#     Concept 1971 -> 0.00128
#     Concept 6039 -> 0.00070
#     Concept 3963 -> 0.00055
#     Concept 1758 -> 0.00015
#     Concept 2621 -> 0.00013
#     Concept 3304 -> -0.00243
#     Concept 4955 -> -0.00165
#     Concept 4458 -> -0.00132
#     Concept 1746 -> -0.00082
#     Concept 354 -> -0.00036
#     Concept 4409 -> -0.00033
# Aggregated
#     Concept 573 -> 1.39597
#     Concept 2887 -> 0.52560
#     Concept 1428 -> 0.26966
#     Concept 3304 -> 0.17525
#     Concept 5797 -> 0.16873
#     Concept 1037 -> 0.15895
#     Concept 3271 -> 0.15812
#     Concept 1611 -> 0.10579
#     Concept 4955 -> 0.10543
#     Concept 210 -> 0.10478
#     Concept 1317 -> 0.09149
#     Concept 4458 -> 0.08438
#     Concept 1971 -> 0.08185
#     Concept 1746 -> 0.05266
#     Concept 6039 -> 0.04496
#     Concept 3963 -> 0.03547
#     Concept 1543 -> 0.02402
#     Concept 354 -> 0.02336
#     Concept 4409 -> 0.02143
#     Concept 4373 -> 0.02060
#     Concept 2051 -> 0.01413
#     Concept 1758 -> 0.00950
#     Concept 2621 -> 0.00835
#
# Class 27 ============================================================
# Domain: INET
#     Concept 1945 -> 0.00207
#     Concept 5614 -> 0.00087
#     Concept 4967 -> 0.00010
#     Concept 3848 -> 0.00009
#     Concept 549 -> 0.00009
#     Concept 354 -> 0.00008
#     Concept 1555 -> 0.00008
#     Concept 2898 -> 0.00008
#     Concept 561 -> 0.00007
#     Concept 2360 -> 0.00007
#     Concept 5797 -> 0.00006
#     Concept 1543 -> 0.00006
#     Concept 3084 -> 0.00005
#     Concept 5428 -> 0.00005
#     Concept 3470 -> 0.00004
#     Concept 1872 -> 0.00004
#     Concept 2614 -> 0.00004
#     Concept 2393 -> 0.00003
#     Concept 1353 -> -0.00006
#     Concept 1971 -> -0.00004
# Domain: Sketch
#     Concept 1945 -> 0.00477
#     Concept 5614 -> 0.00403
#     Concept 2077 -> 0.00218
#     Concept 1971 -> 0.00196
#     Concept 3304 -> 0.00127
#     Concept 1611 -> 0.00024
#     Concept 5797 -> 0.00017
#     Concept 4955 -> -0.00100
# Aggregated
#     Concept 1945 -> 0.90007
#     Concept 5614 -> 0.50890
#     Concept 2077 -> 0.13946
#     Concept 1971 -> 0.13526
#     Concept 3304 -> 0.08128
#     Concept 4955 -> 0.06427
#     Concept 5797 -> 0.02937
#     Concept 4967 -> 0.02755
#     Concept 3848 -> 0.02713
#     Concept 549 -> 0.02588
#     Concept 354 -> 0.02289
#     Concept 1555 -> 0.02212
#     Concept 2898 -> 0.02168
#     Concept 561 -> 0.02009
#     Concept 2360 -> 0.01977
#     Concept 1543 -> 0.01865
#     Concept 1353 -> 0.01664
#     Concept 3084 -> 0.01573
#     Concept 1611 -> 0.01518
#     Concept 5428 -> 0.01422
#     Concept 3470 -> 0.01218
#     Concept 1872 -> 0.01072
#     Concept 2614 -> 0.01029
#     Concept 2393 -> 0.00960
#
# Class 28 ============================================================
# Domain: INET
#     Concept 2105 -> 0.00285
#     Concept 1037 -> 0.00019
#     Concept 1971 -> 0.00009
#     Concept 2597 -> 0.00006
# Domain: Sketch
#     Concept 1037 -> 0.00390
#     Concept 2105 -> 0.00296
#     Concept 4816 -> 0.00293
#     Concept 3304 -> 0.00231
#     Concept 1971 -> 0.00100
#     Concept 3394 -> 0.00069
#     Concept 1611 -> 0.00059
#     Concept 5797 -> 0.00056
#     Concept 354 -> 0.00028
#     Concept 573 -> 0.00027
#     Concept 3271 -> 0.00022
#     Concept 1543 -> 0.00020
# Aggregated
#     Concept 2105 -> 1.01059
#     Concept 1037 -> 0.30534
#     Concept 4816 -> 0.18786
#     Concept 3304 -> 0.14777
#     Concept 1971 -> 0.08877
#     Concept 3394 -> 0.04386
#     Concept 1611 -> 0.03790
#     Concept 5797 -> 0.03556
#     Concept 354 -> 0.01785
#     Concept 2597 -> 0.01777
#     Concept 573 -> 0.01729
#     Concept 3271 -> 0.01413
#     Concept 1543 -> 0.01301
#
# Class 29 ============================================================
# Domain: INET
#     Concept 354 -> 0.00259
#     Concept 2597 -> 0.00036
#     Concept 2040 -> 0.00027
#     Concept 4154 -> 0.00019
#     Concept 3401 -> 0.00018
#     Concept 5539 -> 0.00017
#     Concept 5025 -> 0.00012
#     Concept 5660 -> 0.00010
#     Concept 949 -> 0.00009
#     Concept 1354 -> 0.00009
#     Concept 1226 -> 0.00006
#     Concept 1971 -> 0.00004
#     Concept 2139 -> -0.00012
#     Concept 353 -> -0.00008
#     Concept 661 -> -0.00008
#     Concept 1945 -> -0.00008
#     Concept 1543 -> -0.00008
#     Concept 1037 -> -0.00007
#     Concept 3304 -> -0.00006
#     Concept 4329 -> -0.00004
#     Concept 4041 -> -0.00004
#     Concept 5246 -> -0.00004
#     Concept 210 -> -0.00004
# Domain: Sketch
#     Concept 354 -> 0.00350
#     Concept 3271 -> 0.00208
#     Concept 3304 -> 0.00145
#     Concept 1971 -> 0.00101
#     Concept 3478 -> 0.00066
#     Concept 5594 -> 0.00051
# Aggregated
#     Concept 354 -> 0.96955
#     Concept 3271 -> 0.13340
#     Concept 3304 -> 0.10917
#     Concept 2597 -> 0.10423
#     Concept 2040 -> 0.07763
#     Concept 1971 -> 0.07739
#     Concept 4154 -> 0.05422
#     Concept 3401 -> 0.05149
#     Concept 5539 -> 0.04947
#     Concept 3478 -> 0.04220
#     Concept 2139 -> 0.03480
#     Concept 5025 -> 0.03479
#     Concept 5594 -> 0.03259
#     Concept 5660 -> 0.03005
#     Concept 949 -> 0.02538
#     Concept 1354 -> 0.02508
#     Concept 353 -> 0.02316
#     Concept 661 -> 0.02260
#     Concept 1945 -> 0.02246
#     Concept 1543 -> 0.02185
#     Concept 1037 -> 0.02019
#     Concept 1226 -> 0.01649
#     Concept 4329 -> 0.01218
#     Concept 4041 -> 0.01093
#     Concept 5246 -> 0.01035
#     Concept 210 -> 0.01033
#
# Class 30 ============================================================
# Domain: INET
#     Concept 949 -> 0.00309
#     Concept 1945 -> 0.00040
#     Concept 3874 -> 0.00030
#     Concept 3042 -> 0.00023
#     Concept 4259 -> 0.00014
#     Concept 1644 -> 0.00013
#     Concept 3192 -> 0.00012
#     Concept 1353 -> 0.00011
#     Concept 5734 -> 0.00008
#     Concept 1072 -> 0.00008
#     Concept 2543 -> 0.00008
#     Concept 5979 -> 0.00007
#     Concept 3304 -> 0.00007
#     Concept 4571 -> 0.00007
#     Concept 1971 -> 0.00006
#     Concept 1543 -> 0.00005
#     Concept 3465 -> 0.00005
#     Concept 2593 -> 0.00005
#     Concept 5614 -> 0.00005
#     Concept 435 -> 0.00004
#     Concept 4286 -> 0.00004
#     Concept 5025 -> 0.00004
#     Concept 1094 -> 0.00004
#     Concept 2354 -> 0.00004
#     Concept 2757 -> 0.00004
#     Concept 2597 -> 0.00004
#     Concept 16 -> 0.00003
#     Concept 4358 -> 0.00003
#     Concept 4123 -> -0.00009
#     Concept 5724 -> -0.00004
# Domain: Sketch
# Aggregated
#     Concept 949 -> 0.88916
#     Concept 1945 -> 0.11642
#     Concept 3874 -> 0.08652
#     Concept 3042 -> 0.06688
#     Concept 4259 -> 0.04105
#     Concept 1644 -> 0.03717
#     Concept 3192 -> 0.03396
#     Concept 1353 -> 0.03271
#     Concept 4123 -> 0.02583
#     Concept 5734 -> 0.02430
#     Concept 1072 -> 0.02390
#     Concept 2543 -> 0.02268
#     Concept 5979 -> 0.02113
#     Concept 3304 -> 0.02056
#     Concept 4571 -> 0.01886
#     Concept 1971 -> 0.01809
#     Concept 1543 -> 0.01580
#     Concept 3465 -> 0.01505
#     Concept 2593 -> 0.01360
#     Concept 5614 -> 0.01337
#     Concept 435 -> 0.01293
#     Concept 4286 -> 0.01289
#     Concept 5025 -> 0.01231
#     Concept 1094 -> 0.01208
#     Concept 2354 -> 0.01201
#     Concept 2757 -> 0.01174
#     Concept 2597 -> 0.01147
#     Concept 5724 -> 0.01020
#     Concept 16 -> 0.01006
#     Concept 4358 -> 0.00970
#
# Class 31 ============================================================
# Domain: INET
#     Concept 1206 -> 0.00192
#     Concept 505 -> 0.00088
#     Concept 5869 -> 0.00019
#     Concept 689 -> 0.00015
#     Concept 1971 -> 0.00014
#     Concept 3304 -> -0.00011
#     Concept 4968 -> -0.00004
# Domain: Sketch
#     Concept 505 -> 0.00346
#     Concept 1206 -> 0.00247
#     Concept 1971 -> 0.00181
#     Concept 5797 -> 0.00110
#     Concept 1611 -> 0.00087
# Aggregated
#     Concept 1206 -> 0.71035
#     Concept 505 -> 0.47534
#     Concept 1971 -> 0.15511
#     Concept 5797 -> 0.07011
#     Concept 1611 -> 0.05596
#     Concept 5869 -> 0.05522
#     Concept 689 -> 0.04305
#     Concept 3304 -> 0.03104
#     Concept 4968 -> 0.01104
#
# Class 32 ============================================================
# Domain: INET
#     Concept 3245 -> 0.00251
#     Concept 5252 -> 0.00074
#     Concept 974 -> 0.00011
#     Concept 4069 -> 0.00008
#     Concept 1325 -> 0.00008
#     Concept 5492 -> 0.00007
#     Concept 419 -> 0.00007
#     Concept 4154 -> 0.00007
#     Concept 5459 -> 0.00006
#     Concept 1543 -> 0.00005
#     Concept 3963 -> 0.00005
#     Concept 947 -> 0.00005
# Domain: Sketch
#     Concept 5252 -> 0.00284
#     Concept 3245 -> 0.00273
#     Concept 1971 -> 0.00255
#     Concept 1611 -> 0.00023
#     Concept 2262 -> 0.00014
# Aggregated
#     Concept 3245 -> 0.89769
#     Concept 5252 -> 0.39405
#     Concept 1971 -> 0.16337
#     Concept 974 -> 0.03028
#     Concept 4069 -> 0.02422
#     Concept 1325 -> 0.02213
#     Concept 5492 -> 0.02148
#     Concept 419 -> 0.02061
#     Concept 4154 -> 0.01971
#     Concept 5459 -> 0.01752
#     Concept 1543 -> 0.01507
#     Concept 3963 -> 0.01496
#     Concept 1611 -> 0.01460
#     Concept 947 -> 0.01433
#     Concept 2262 -> 0.00891
#
# Class 33 ============================================================
# Domain: INET
#     Concept 4742 -> 0.00325
#     Concept 4012 -> 0.00067
#     Concept 1543 -> 0.00007
#     Concept 1971 -> 0.00005
#     Concept 4917 -> 0.00005
#     Concept 3304 -> 0.00004
#     Concept 2791 -> 0.00004
# Domain: Sketch
#     Concept 1971 -> 0.00251
#     Concept 5869 -> 0.00149
#     Concept 3625 -> 0.00107
#     Concept 1611 -> 0.00074
#     Concept 210 -> 0.00035
#     Concept 2791 -> 0.00024
# Aggregated
#     Concept 4742 -> 0.93452
#     Concept 4012 -> 0.19304
#     Concept 1971 -> 0.17560
#     Concept 5869 -> 0.09566
#     Concept 3625 -> 0.06847
#     Concept 1611 -> 0.04746
#     Concept 2791 -> 0.02730
#     Concept 210 -> 0.02240
#     Concept 1543 -> 0.01932
#     Concept 4917 -> 0.01321
#     Concept 3304 -> 0.01273
#
# Class 34 ============================================================
# Domain: INET
#     Concept 3880 -> 0.00314
#     Concept 4012 -> 0.00051
#     Concept 3744 -> 0.00024
#     Concept 5771 -> 0.00019
#     Concept 3304 -> 0.00015
#     Concept 2354 -> 0.00015
#     Concept 487 -> 0.00015
#     Concept 5759 -> 0.00013
#     Concept 2353 -> 0.00010
#     Concept 1971 -> 0.00010
#     Concept 24 -> 0.00006
#     Concept 1987 -> 0.00004
#     Concept 2051 -> 0.00004
#     Concept 5638 -> 0.00004
# Domain: Sketch
#     Concept 1971 -> 0.00273
#     Concept 1611 -> 0.00025
# Aggregated
#     Concept 3880 -> 0.90458
#     Concept 1971 -> 0.20356
#     Concept 4012 -> 0.14652
#     Concept 3744 -> 0.06794
#     Concept 5771 -> 0.05405
#     Concept 3304 -> 0.04282
#     Concept 2354 -> 0.04280
#     Concept 487 -> 0.04193
#     Concept 5759 -> 0.03712
#     Concept 2353 -> 0.02878
#     Concept 24 -> 0.01763
#     Concept 1611 -> 0.01595
#     Concept 1987 -> 0.01139
#     Concept 2051 -> 0.01101
#     Concept 5638 -> 0.01049
#
# Class 35 ============================================================
# Domain: INET
#     Concept 3042 -> 0.00247
#     Concept 3580 -> 0.00158
#     Concept 5771 -> 0.00088
#     Concept 4123 -> 0.00070
#     Concept 5218 -> 0.00037
#     Concept 1424 -> 0.00014
#     Concept 3304 -> 0.00010
#     Concept 3941 -> 0.00008
#     Concept 2121 -> 0.00007
#     Concept 5532 -> 0.00005
#     Concept 1495 -> 0.00004
#     Concept 1876 -> -0.00019
# Domain: Sketch
# Aggregated
#     Concept 3042 -> 0.70955
#     Concept 3580 -> 0.45374
#     Concept 5771 -> 0.25189
#     Concept 4123 -> 0.20071
#     Concept 5218 -> 0.10647
#     Concept 1876 -> 0.05426
#     Concept 1424 -> 0.03887
#     Concept 3304 -> 0.02978
#     Concept 3941 -> 0.02159
#     Concept 2121 -> 0.01929
#     Concept 5532 -> 0.01567
#     Concept 1495 -> 0.01071
#
# Class 36 ============================================================
# Domain: INET
#     Concept 2004 -> 0.00279
#     Concept 4160 -> 0.00093
#     Concept 1971 -> 0.00011
#     Concept 3074 -> 0.00007
#     Concept 3304 -> 0.00007
#     Concept 2938 -> 0.00006
#     Concept 3693 -> 0.00005
#     Concept 1424 -> 0.00004
#     Concept 6113 -> 0.00003
#     Concept 5481 -> -0.00012
#     Concept 5076 -> -0.00005
# Domain: Sketch
#     Concept 1971 -> 0.00265
#     Concept 4160 -> 0.00121
#     Concept 3304 -> 0.00034
#     Concept 2004 -> 0.00027
#     Concept 2353 -> 0.00013
# Aggregated
#     Concept 2004 -> 0.81946
#     Concept 4160 -> 0.34580
#     Concept 1971 -> 0.20193
#     Concept 3304 -> 0.04102
#     Concept 5481 -> 0.03381
#     Concept 3074 -> 0.01965
#     Concept 2938 -> 0.01591
#     Concept 5076 -> 0.01564
#     Concept 3693 -> 0.01421
#     Concept 1424 -> 0.01245
#     Concept 6113 -> 0.00995
#     Concept 2353 -> 0.00853
#
# Class 37 ============================================================
# Domain: INET
#     Concept 2791 -> 0.00225
#     Concept 3262 -> 0.00096
# ...
#     Concept 2574 -> 0.01267
#     Concept 4069 -> 0.01207
#     Concept 5189 -> 0.01046
#     Concept 5757 -> 0.00983
#
# Class 83 ============================================================
# Domain: INET
#     Concept 620 -> 0.00156
#     Concept 4407 -> 0.00129
#     Concept 3395 -> 0.00119
#     Concept 587 -> 0.00017
#     Concept 1758 -> 0.00015
#     Concept 4547 -> 0.00008
#     Concept 1543 -> 0.00008
#     Concept 5594 -> 0.00008
#     Concept 1555 -> 0.00006
#     Concept 5081 -> 0.00005
#     Concept 2621 -> 0.00005
#     Concept 4989 -> 0.00004
#     Concept 2486 -> 0.00004
#     Concept 794 -> -0.00004
# Domain: Sketch
#     Concept 3395 -> 0.00515
#     Concept 620 -> 0.00390
#     Concept 1971 -> 0.00173
#     Concept 5360 -> 0.00145
# Aggregated
#     Concept 620 -> 0.69808
#     Concept 3395 -> 0.67275
#     Concept 4407 -> 0.37196
#     Concept 1971 -> 0.11092
#     Concept 5360 -> 0.09251
#     Concept 587 -> 0.04899
#     Concept 1758 -> 0.04214
#     Concept 4547 -> 0.02310
#     Concept 1543 -> 0.02236
#     Concept 5594 -> 0.02202
#     Concept 1555 -> 0.01626
#     Concept 5081 -> 0.01561
#     Concept 2621 -> 0.01449
#     Concept 4989 -> 0.01027
#     Concept 794 -> 0.01023
#     Concept 2486 -> 0.01021
#
# Class 84 ============================================================
# Domain: INET
#     Concept 3047 -> 0.00258
#     Concept 4276 -> 0.00118
# Domain: Sketch
#     Concept 3047 -> 0.00322
#     Concept 1971 -> 0.00257
#     Concept 5797 -> 0.00241
#     Concept 2621 -> 0.00186
#     Concept 1611 -> 0.00055
#     Concept 3395 -> 0.00047
#     Concept 801 -> 0.00023
#     Concept 1758 -> 0.00016
#     Concept 3304 -> -0.00839
#     Concept 5259 -> -0.00155
# Aggregated
#     Concept 3047 -> 0.94791
#     Concept 3304 -> 0.53709
#     Concept 4276 -> 0.33828
#     Concept 1971 -> 0.16423
#     Concept 5797 -> 0.15433
#     Concept 2621 -> 0.11908
#     Concept 5259 -> 0.09936
#     Concept 1611 -> 0.03495
#     Concept 3395 -> 0.03015
#     Concept 801 -> 0.01462
#     Concept 1758 -> 0.01024
#
# Class 85 ============================================================
# Domain: INET
#     Concept 1254 -> 0.00257
#     Concept 6058 -> 0.00065
#     Concept 1065 -> 0.00010
#     Concept 4857 -> 0.00008
#     Concept 1066 -> 0.00008
#     Concept 2360 -> 0.00007
#     Concept 4347 -> 0.00007
#     Concept 5825 -> 0.00007
#     Concept 1562 -> 0.00007
#     Concept 337 -> 0.00006
#     Concept 4967 -> 0.00006
#     Concept 5021 -> 0.00005
#     Concept 3848 -> 0.00005
#     Concept 5149 -> 0.00005
#     Concept 1072 -> 0.00004
#     Concept 3296 -> 0.00004
# Domain: Sketch
#     Concept 1254 -> 0.00541
#     Concept 1611 -> 0.00189
#     Concept 1971 -> 0.00143
#     Concept 5797 -> 0.00102
# Aggregated
#     Concept 1254 -> 1.08455
#     Concept 6058 -> 0.18830
#     Concept 1611 -> 0.12129
#     Concept 1971 -> 0.09131
#     Concept 5797 -> 0.06517
#     Concept 1065 -> 0.02855
#     Concept 4857 -> 0.02339
#     Concept 1066 -> 0.02214
#     Concept 2360 -> 0.02006
#     Concept 4347 -> 0.01999
#     Concept 5825 -> 0.01954
#     Concept 1562 -> 0.01919
#     Concept 337 -> 0.01836
#     Concept 4967 -> 0.01826
#     Concept 5021 -> 0.01466
#     Concept 3848 -> 0.01396
#     Concept 5149 -> 0.01383
#     Concept 1072 -> 0.01283
#     Concept 3296 -> 0.01104
#
# Class 86 ============================================================
# Domain: INET
#     Concept 3198 -> 0.00227
#     Concept 4959 -> 0.00113
#     Concept 5596 -> 0.00006
# Domain: Sketch
#     Concept 3198 -> 0.00234
#     Concept 1611 -> 0.00158
#     Concept 3304 -> 0.00137
#     Concept 4955 -> 0.00055
#     Concept 4959 -> 0.00050
#     Concept 5594 -> 0.00025
# Aggregated
#     Concept 3198 -> 0.80348
#     Concept 4959 -> 0.35874
#     Concept 1611 -> 0.10099
#     Concept 3304 -> 0.08743
#     Concept 4955 -> 0.03507
#     Concept 5596 -> 0.01834
#     Concept 5594 -> 0.01601
#
# Class 87 ============================================================
# Domain: INET
#     Concept 522 -> 0.00207
#     Concept 2212 -> 0.00100
#     Concept 3225 -> 0.00007
#     Concept 4067 -> 0.00006
#     Concept 3304 -> 0.00005
# Domain: Sketch
#     Concept 522 -> 0.01191
#     Concept 3478 -> 0.00353
#     Concept 4955 -> 0.00248
#     Concept 5594 -> 0.00176
#     Concept 5797 -> 0.00154
#     Concept 1611 -> 0.00095
#     Concept 483 -> 0.00066
#     Concept 1543 -> 0.00043
#     Concept 1971 -> -0.00084
#     Concept 1758 -> -0.00076
#     Concept 3304 -> -0.00030
# Aggregated
#     Concept 522 -> 1.35721
#     Concept 2212 -> 0.28681
#     Concept 3478 -> 0.22602
#     Concept 4955 -> 0.15885
#     Concept 5594 -> 0.11289
#     Concept 5797 -> 0.09865
#     Concept 1611 -> 0.06072
#     Concept 1971 -> 0.05378
#     Concept 1758 -> 0.04895
#     Concept 483 -> 0.04216
#     Concept 3304 -> 0.03208
#     Concept 1543 -> 0.02731
#     Concept 3225 -> 0.01988
#     Concept 4067 -> 0.01801
#
# Class 88 ============================================================
# Domain: INET
#     Concept 3783 -> 0.00174
#     Concept 4220 -> 0.00102
#     Concept 2621 -> 0.00007
#     Concept 1983 -> 0.00006
#     Concept 483 -> 0.00006
#     Concept 4002 -> 0.00005
#     Concept 2212 -> 0.00005
#     Concept 1641 -> 0.00005
#     Concept 5797 -> 0.00005
#     Concept 135 -> 0.00005
#     Concept 60 -> 0.00004
#     Concept 2640 -> 0.00004
#     Concept 4018 -> 0.00004
#     Concept 522 -> 0.00004
# Domain: Sketch
#     Concept 4220 -> 0.00324
#     Concept 1971 -> 0.00302
#     Concept 3783 -> 0.00138
#     Concept 1983 -> 0.00097
#     Concept 5594 -> 0.00033
#     Concept 3304 -> -0.00144
# Aggregated
#     Concept 3783 -> 0.58988
#     Concept 4220 -> 0.49993
#     Concept 1971 -> 0.19307
#     Concept 3304 -> 0.09194
#     Concept 1983 -> 0.07875
#     Concept 5594 -> 0.02129
#     Concept 2621 -> 0.01976
#     Concept 483 -> 0.01606
#     Concept 4002 -> 0.01551
#     Concept 2212 -> 0.01494
#     Concept 1641 -> 0.01493
#     Concept 5797 -> 0.01366
#     Concept 135 -> 0.01326
#     Concept 60 -> 0.01114
#     Concept 2640 -> 0.01111
#     Concept 4018 -> 0.01075
#     Concept 522 -> 0.01010
#
# Class 89 ============================================================
# Domain: INET
#     Concept 728 -> 0.00186
#     Concept 212 -> 0.00146
#     Concept 627 -> 0.00014
#     Concept 3304 -> 0.00004
# Domain: Sketch
#     Concept 728 -> 0.01100
#     Concept 1971 -> 0.00313
#     Concept 4086 -> 0.00170
#     Concept 3304 -> 0.00155
#     Concept 2310 -> 0.00125
#     Concept 3504 -> 0.00081
#     Concept 1611 -> -0.00255
#     Concept 5797 -> -0.00018
# Aggregated
#     Concept 728 -> 1.23902
#     Concept 212 -> 0.42115
#     Concept 1971 -> 0.20047
#     Concept 1611 -> 0.16348
#     Concept 3304 -> 0.11142
#     Concept 4086 -> 0.10886
#     Concept 2310 -> 0.08003
#     Concept 3504 -> 0.05203
#     Concept 627 -> 0.04091
#     Concept 5797 -> 0.01150
#
# Class 90 ============================================================
# Domain: INET
#     Concept 2418 -> 0.00240
#     Concept 4823 -> 0.00066
#     Concept 2797 -> 0.00003
#     Concept 960 -> 0.00003
# Domain: Sketch
#     Concept 2418 -> 0.00671
#     Concept 4220 -> 0.00502
#     Concept 2212 -> 0.00398
#     Concept 5505 -> 0.00308
#     Concept 483 -> 0.00253
#     Concept 1611 -> 0.00242
#     Concept 1746 -> 0.00224
#     Concept 1971 -> 0.00217
#     Concept 5429 -> 0.00040
#     Concept 3304 -> -0.00486
#     Concept 1543 -> -0.00392
#     Concept 3478 -> -0.00319
#     Concept 1555 -> -0.00058
#     Concept 2621 -> -0.00044
#     Concept 4967 -> -0.00019
# Aggregated
#     Concept 2418 -> 1.12147
#     Concept 4220 -> 0.32155
#     Concept 3304 -> 0.31109
#     Concept 2212 -> 0.25453
#     Concept 1543 -> 0.25083
#     Concept 3478 -> 0.20400
#     Concept 5505 -> 0.19709
#     Concept 4823 -> 0.19048
#     Concept 483 -> 0.16182
#     Concept 1611 -> 0.15509
#     Concept 1746 -> 0.14354
#     Concept 1971 -> 0.13906
#     Concept 1555 -> 0.03722
#     Concept 2621 -> 0.02812
#     Concept 5429 -> 0.02571
#     Concept 4967 -> 0.01221
#     Concept 2797 -> 0.00991
#     Concept 960 -> 0.00977
#
# Class 91 ============================================================
# Domain: INET
#     Concept 2684 -> 0.00170
#     Concept 4109 -> 0.00112
# Domain: Sketch
#     Concept 2684 -> 0.00859
#     Concept 4480 -> 0.00236
#     Concept 1971 -> 0.00208
#     Concept 3304 -> 0.00176
#     Concept 3478 -> 0.00146
#     Concept 5594 -> 0.00080
#     Concept 5797 -> -0.00212
#     Concept 1317 -> -0.00063
#     Concept 3198 -> -0.00060
#     Concept 1611 -> -0.00040
# Aggregated
#     Concept 2684 -> 1.04037
#     Concept 4109 -> 0.32241
#     Concept 4480 -> 0.15127
#     Concept 5797 -> 0.13561
#     Concept 1971 -> 0.13346
#     Concept 3304 -> 0.11291
#     Concept 3478 -> 0.09337
#     Concept 5594 -> 0.05096
#     Concept 1317 -> 0.04048
#     Concept 3198 -> 0.03852
#     Concept 1611 -> 0.02591
#
# Class 92 ============================================================
# Domain: INET
#     Concept 3393 -> 0.00229
#     Concept 4614 -> 0.00094
# Domain: Sketch
#     Concept 1331 -> 0.01128
#     Concept 3393 -> 0.00425
#     Concept 3304 -> 0.00334
#     Concept 3423 -> 0.00151
#     Concept 5594 -> 0.00131
#     Concept 6009 -> 0.00078
#     Concept 1611 -> 0.00033
#     Concept 4614 -> 0.00019
#     Concept 652 -> -0.00084
#     Concept 2621 -> -0.00062
#     Concept 1971 -> -0.00044
# Aggregated
#     Concept 3393 -> 0.93184
#     Concept 1331 -> 0.72214
#     Concept 4614 -> 0.28222
#     Concept 3304 -> 0.21400
#     Concept 3423 -> 0.09686
#     Concept 5594 -> 0.08404
#     Concept 652 -> 0.05407
#     Concept 6009 -> 0.05006
#     Concept 2621 -> 0.03996
#     Concept 1971 -> 0.02810
#     Concept 1611 -> 0.02144
#
# Class 93 ============================================================
# Domain: INET
#     Concept 1294 -> 0.00170
#     Concept 2889 -> 0.00148
# Domain: Sketch
#     Concept 1294 -> 0.00748
#     Concept 1971 -> 0.00146
# Aggregated
#     Concept 1294 -> 0.96820
#     Concept 2889 -> 0.42546
#     Concept 1971 -> 0.09363
#
# Class 94 ============================================================
# Domain: INET
#     Concept 5900 -> 0.00169
#     Concept 5598 -> 0.00164
#     Concept 6094 -> 0.00034
#     Concept 3000 -> 0.00031
#     Concept 1839 -> 0.00025
#     Concept 1971 -> 0.00014
#     Concept 3304 -> -0.00005
#     Concept 862 -> -0.00004
#     Concept 4614 -> -0.00004
# Domain: Sketch
#     Concept 5357 -> 0.00592
#     Concept 5900 -> 0.00435
#     Concept 627 -> 0.00376
#     Concept 5598 -> 0.00354
#     Concept 5069 -> 0.00348
#     Concept 1971 -> 0.00339
#     Concept 675 -> 0.00314
#     Concept 4955 -> 0.00232
#     Concept 5172 -> 0.00172
#     Concept 1317 -> 0.00143
#     Concept 3958 -> 0.00138
#     Concept 5594 -> 0.00127
#     Concept 2684 -> 0.00048
#     Concept 1641 -> -0.00314
#     Concept 2621 -> -0.00266
#     Concept 2183 -> -0.00266
#     Concept 2614 -> -0.00214
#     Concept 5721 -> -0.00152
#     Concept 3304 -> -0.00122
#     Concept 1543 -> -0.00103
#     Concept 1027 -> -0.00092
#     Concept 3504 -> -0.00058
#     Concept 1611 -> -0.00051
#     Concept 3478 -> -0.00023
#     Concept 210 -> -0.00020
# Aggregated
#     Concept 5900 -> 0.76437
#     Concept 5598 -> 0.69906
#     Concept 5357 -> 0.37877
#     Concept 1971 -> 0.25727
#     Concept 627 -> 0.24039
#     Concept 5069 -> 0.22246
#     Concept 675 -> 0.20120
#     Concept 1641 -> 0.20112
#     Concept 2621 -> 0.17050
#     Concept 2183 -> 0.17047
#     Concept 4955 -> 0.14856
#     Concept 2614 -> 0.13705
#     Concept 5172 -> 0.11041
#     Concept 6094 -> 0.09892
#     Concept 5721 -> 0.09753
#     Concept 3304 -> 0.09161
#     Concept 1317 -> 0.09153
#     Concept 3958 -> 0.08838
#     Concept 3000 -> 0.08825
#     Concept 5594 -> 0.08119
#     Concept 1839 -> 0.07051
#     Concept 1543 -> 0.06565
#     Concept 1027 -> 0.05883
#     Concept 3504 -> 0.03702
#     Concept 1611 -> 0.03282
#     Concept 2684 -> 0.03104
#     Concept 3478 -> 0.01466
#     Concept 210 -> 0.01287
#     Concept 862 -> 0.01217
#     Concept 4614 -> 0.01117
#
# Class 95 ============================================================
# Domain: INET
#     Concept 4514 -> 0.00284
#     Concept 1099 -> 0.00065
#     Concept 5069 -> 0.00004
# Domain: Sketch
#     Concept 5172 -> 0.00348
#     Concept 4514 -> 0.00344
#     Concept 1543 -> 0.00338
#     Concept 1099 -> 0.00264
#     Concept 5357 -> 0.00178
#     Concept 1971 -> 0.00176
#     Concept 3304 -> 0.00140
#     Concept 1758 -> 0.00108
#     Concept 5069 -> 0.00069
#     Concept 3979 -> 0.00044
#     Concept 675 -> 0.00023
#     Concept 1611 -> -0.00122
# Aggregated
#     Concept 4514 -> 1.03641
#     Concept 1099 -> 0.35549
#     Concept 5172 -> 0.22299
#     Concept 1543 -> 0.21656
#     Concept 5357 -> 0.11370
#     Concept 1971 -> 0.11279
#     Concept 3304 -> 0.08968
#     Concept 1611 -> 0.07815
#     Concept 1758 -> 0.06890
#     Concept 5069 -> 0.05448
#     Concept 3979 -> 0.02833
#     Concept 675 -> 0.01490
#
# Class 96 ============================================================
# Domain: INET
#     Concept 1900 -> 0.00179
#     Concept 5272 -> 0.00112
#     Concept 1821 -> 0.00019
#     Concept 1543 -> -0.00005
#     Concept 5234 -> -0.00004
# Domain: Sketch
#     Concept 1900 -> 0.00540
#     Concept 5272 -> 0.00305
#     Concept 3304 -> 0.00213
#     Concept 1611 -> 0.00060
#     Concept 2621 -> 0.00042
# Aggregated
#     Concept 1900 -> 0.85952
#     Concept 5272 -> 0.51802
#     Concept 3304 -> 0.13625
#     Concept 1821 -> 0.05487
#     Concept 1611 -> 0.03863
#     Concept 2621 -> 0.02677
#     Concept 1543 -> 0.01331
#     Concept 5234 -> 0.01066
#
# Class 97 ============================================================
# Domain: INET
#     Concept 2381 -> 0.00236
#     Concept 1141 -> 0.00072
#     Concept 627 -> 0.00019
#     Concept 1971 -> 0.00011
#     Concept 5527 -> 0.00010
#     Concept 522 -> 0.00010
#     Concept 2253 -> 0.00009
#     Concept 559 -> 0.00008
#     Concept 5631 -> 0.00006
#     Concept 3401 -> 0.00005
#     Concept 1929 -> 0.00005
#     Concept 5089 -> 0.00005
#     Concept 3304 -> 0.00005
#     Concept 4984 -> 0.00004
# Domain: Sketch
#     Concept 2396 -> 0.00757
#     Concept 2381 -> 0.00498
#     Concept 3304 -> 0.00330
#     Concept 1141 -> 0.00302
#     Concept 507 -> 0.00247
#     Concept 2295 -> 0.00203
#     Concept 2184 -> 0.00201
#     Concept 1971 -> 0.00151
#     Concept 2614 -> 0.00103
#     Concept 5594 -> -0.00150
#     Concept 1611 -> -0.00145
# Aggregated
#     Concept 2381 -> 0.99671
#     Concept 2396 -> 0.48465
#     Concept 1141 -> 0.40045
#     Concept 3304 -> 0.22415
#     Concept 507 -> 0.15787
#     Concept 2295 -> 0.12992
#     Concept 2184 -> 0.12878
#     Concept 1971 -> 0.12721
#     Concept 5594 -> 0.09612
#     Concept 1611 -> 0.09250
#     Concept 2614 -> 0.06562
#     Concept 627 -> 0.05527
#     Concept 5527 -> 0.02990
#     Concept 522 -> 0.02864
#     Concept 2253 -> 0.02617
#     Concept 559 -> 0.02344
#     Concept 5631 -> 0.01586
#     Concept 3401 -> 0.01578
#     Concept 1929 -> 0.01496
#     Concept 5089 -> 0.01456
#     Concept 4984 -> 0.01188
#
# Class 98 ============================================================
# Domain: INET
#     Concept 2582 -> 0.00196
#     Concept 5375 -> 0.00140
#     Concept 1676 -> 0.00052
#     Concept 1717 -> 0.00007
#     Concept 4976 -> 0.00007
#     Concept 3304 -> 0.00005
#     Concept 2065 -> -0.00004
# Domain: Sketch
#     Concept 1676 -> 0.00762
#     Concept 2582 -> 0.00392
#     Concept 483 -> 0.00314
#     Concept 3304 -> 0.00285
#     Concept 2141 -> 0.00183
#     Concept 4458 -> 0.00130
#     Concept 1611 -> 0.00125
#     Concept 5375 -> 0.00089
#     Concept 5357 -> 0.00014
#     Concept 5797 -> -0.00092
# Aggregated
#     Concept 2582 -> 0.81506
#     Concept 1676 -> 0.63830
#     Concept 5375 -> 0.45833
#     Concept 483 -> 0.20127
#     Concept 3304 -> 0.19540
#     Concept 2141 -> 0.11734
#     Concept 4458 -> 0.08303
#     Concept 1611 -> 0.07979
#     Concept 5797 -> 0.05889
#     Concept 1717 -> 0.01910
#     Concept 4976 -> 0.01905
#     Concept 2065 -> 0.01234
#     Concept 5357 -> 0.00887
#
# Class 99 ============================================================
# Domain: INET
#     Concept 1363 -> 0.00294
#     Concept 5879 -> 0.00049
#     Concept 3478 -> 0.00045
#     Concept 2184 -> 0.00022
#     Concept 1971 -> 0.00017
#     Concept 4989 -> -0.00010
#     Concept 3304 -> -0.00008
#     Concept 3394 -> -0.00005
#     Concept 4761 -> -0.00004
#     Concept 2076 -> -0.00004
# Domain: Sketch
#     Concept 1363 -> 0.00946
#     Concept 3304 -> 0.00359
#     Concept 1971 -> -0.00020
# Aggregated
#     Concept 1363 -> 1.45083
#     Concept 3304 -> 0.25307
#     Concept 5879 -> 0.14197
#     Concept 3478 -> 0.12931
#     Concept 2184 -> 0.06422
#     Concept 1971 -> 0.06260
#     Concept 4989 -> 0.02783
#     Concept 3394 -> 0.01365
#     Concept 4761 -> 0.01209
#     Concept 2076 -> 0.01014

# %% [markdown]
# ## Old Code

# %%
weights_ood = mlps["Sketch"].weight.detach().cpu()  # shape: (100, 6000)
weights_iid = mlps["INET"].weight.detach().cpu()  # shape: (100, 6000)


aggregator = torch.stack([weights_iid, weights_ood], dim=0)

print("D x C x F")
print(aggregator.shape)


aggregated = aggregator.mean(dim=0)

print(aggregated.shape)
print()
# Out:
# D x C x F
# torch.Size([2, 100, 6144])
# torch.Size([100, 6144])

# %%
import torch

weights_ood = torch.abs(sparse_mlps["Sketch"].weight.detach().cpu())  # shape: (100, 6000)
weights_iid = torch.abs(sparse_mlps["INET"].weight.detach().cpu())  # shape: (100, 6000)

weights = {"OOD": weights_ood, "IID": weights_iid}

nonzero_indices = {}

# Collect nonzero indices per class
for tag, weight in weights.items():
    nonzero_indices[tag] = []
    print(f"\n================ {tag} ==================")
    for class_idx in range(weight.shape[0]):
        # Extract weights for this class
        class_weights = weight[class_idx]

        # Get nonzero indices
        nonzero_idx = torch.nonzero(class_weights, as_tuple=True)[0]

        # Sort by actual weight (positive first, then descending)
        sorted_vals, sorted_idx = torch.sort(
            class_weights[nonzero_idx], descending=True
        )
        sorted_features = nonzero_idx[sorted_idx].tolist()
        sorted_strengths = sorted_vals.tolist()

        nonzero_indices[tag].append(set(sorted_features))

        # Print nicely
        print(f"\nClass {class_idx}: {len(sorted_features)} non-zero features (sorted by weight, positives first)")
        for f_idx, f_val in zip(sorted_features, sorted_strengths):
            print(f"    Feature {f_idx}: weight={f_val:.4f}")

# Print common indices strength-wise
print("\n============== Common Non-Zero Indices ==============")
for class_idx in range(weights_ood.shape[0]):
    common = nonzero_indices["OOD"][class_idx].intersection(nonzero_indices["IID"][class_idx])

    # For strength display, take from OOD & IID separately
    ood_weights = weights["OOD"][class_idx]
    iid_weights = weights["IID"][class_idx]

    # Sort common features by average weight (favoring positive ones)
    common_sorted = sorted(
        list(common),
        key=lambda i: (ood_weights[i] + iid_weights[i]) / 2,
        reverse=True
    )

    print(f"\nClass {class_idx}: {len(common)} common non-zero features (sorted by avg weight)")
    for f_idx in common_sorted:
        print(
            f"    Feature {f_idx}: "
            f"OOD={ood_weights[f_idx]:.4f}, "
            f"IID={iid_weights[f_idx]:.4f}"
        )
# Out:
# ================ OOD ==================
#
# Class 0: 10 non-zero features (sorted by weight, positives first)
#     Feature 606: weight=0.0052
#     Feature 4395: weight=0.0021
#     Feature 1611: weight=0.0017
#     Feature 1543: weight=0.0015
#     Feature 2621: weight=0.0005
#     Feature 3304: weight=0.0005
#     Feature 3736: weight=0.0005
#     Feature 1971: weight=0.0004
#     Feature 757: weight=0.0002
#     Feature 4261: weight=0.0001
#
# Class 1: 5 non-zero features (sorted by weight, positives first)
#     Feature 521: weight=0.0037
#     Feature 1971: weight=0.0025
#     Feature 4261: weight=0.0017
#     Feature 5594: weight=0.0006
#     Feature 136: weight=0.0003
#
# Class 2: 14 non-zero features (sorted by weight, positives first)
#     Feature 92: weight=0.0070
#     Feature 2128: weight=0.0048
#     Feature 448: weight=0.0045
#     Feature 2998: weight=0.0039
#     Feature 1971: weight=0.0029
#     Feature 5636: weight=0.0012
#     Feature 1705: weight=0.0011
#     Feature 1758: weight=0.0009
#     Feature 2621: weight=0.0009
#     Feature 3304: weight=0.0007
#     Feature 4955: weight=0.0005
#     Feature 5461: weight=0.0005
#     Feature 1611: weight=0.0004
#     Feature 2647: weight=0.0003
#
# Class 3: 8 non-zero features (sorted by weight, positives first)
#     Feature 1001: weight=0.0052
#     Feature 4721: weight=0.0043
#     Feature 1971: weight=0.0015
#     Feature 2128: weight=0.0011
#     Feature 1611: weight=0.0005
#     Feature 3304: weight=0.0005
#     Feature 1524: weight=0.0004
#     Feature 2998: weight=0.0001
#
# Class 4: 15 non-zero features (sorted by weight, positives first)
#     Feature 2128: weight=0.0126
#     Feature 3304: weight=0.0061
#     Feature 5636: weight=0.0044
#     Feature 5461: weight=0.0039
#     Feature 1758: weight=0.0039
#     Feature 5797: weight=0.0034
#     Feature 5594: weight=0.0024
#     Feature 2998: weight=0.0017
#     Feature 531: weight=0.0014
#     Feature 2621: weight=0.0008
#     Feature 448: weight=0.0007
#     Feature 4721: weight=0.0006
#     Feature 4955: weight=0.0004
#     Feature 1611: weight=0.0001
#     Feature 1971: weight=0.0001
#
# Class 5: 16 non-zero features (sorted by weight, positives first)
#     Feature 1002: weight=0.0063
#     Feature 2427: weight=0.0053
#     Feature 3767: weight=0.0046
#     Feature 5594: weight=0.0045
#     Feature 5797: weight=0.0033
#     Feature 5974: weight=0.0026
#     Feature 2077: weight=0.0019
#     Feature 3639: weight=0.0015
#     Feature 1746: weight=0.0013
#     Feature 1611: weight=0.0011
#     Feature 3394: weight=0.0008
#     Feature 2621: weight=0.0008
#     Feature 1971: weight=0.0005
#     Feature 1524: weight=0.0003
#     Feature 1919: weight=0.0002
#     Feature 3304: weight=0.0002
#
# Class 6: 4 non-zero features (sorted by weight, positives first)
#     Feature 3304: weight=0.0028
#     Feature 1971: weight=0.0006
#     Feature 4955: weight=0.0006
#     Feature 1758: weight=0.0001
#
# Class 7: 9 non-zero features (sorted by weight, positives first)
#     Feature 4783: weight=0.0077
#     Feature 3985: weight=0.0064
#     Feature 1543: weight=0.0035
#     Feature 1971: weight=0.0030
#     Feature 2077: weight=0.0028
#     Feature 5594: weight=0.0020
#     Feature 4017: weight=0.0019
#     Feature 1611: weight=0.0019
#     Feature 2614: weight=0.0003
#
# Class 8: 10 non-zero features (sorted by weight, positives first)
#     Feature 3985: weight=0.0066
#     Feature 1835: weight=0.0033
#     Feature 3304: weight=0.0027
#     Feature 4017: weight=0.0022
#     Feature 349: weight=0.0020
#     Feature 4783: weight=0.0018
#     Feature 2808: weight=0.0010
#     Feature 5797: weight=0.0009
#     Feature 1971: weight=0.0008
#     Feature 5594: weight=0.0004
#
# Class 9: 0 non-zero features (sorted by weight, positives first)
#
# Class 10: 4 non-zero features (sorted by weight, positives first)
#     Feature 3304: weight=0.0021
#     Feature 637: weight=0.0020
#     Feature 1971: weight=0.0014
#     Feature 5594: weight=0.0012
#
# Class 11: 12 non-zero features (sorted by weight, positives first)
#     Feature 3839: weight=0.0083
#     Feature 2310: weight=0.0018
#     Feature 1971: weight=0.0017
#     Feature 5594: weight=0.0014
#     Feature 2922: weight=0.0013
#     Feature 2874: weight=0.0009
#     Feature 1611: weight=0.0009
#     Feature 2614: weight=0.0009
#     Feature 5994: weight=0.0008
#     Feature 3979: weight=0.0007
#     Feature 549: weight=0.0003
#     Feature 1543: weight=0.0001
#
# Class 12: 4 non-zero features (sorted by weight, positives first)
#     Feature 1502: weight=0.0077
#     Feature 1971: weight=0.0023
#     Feature 1758: weight=0.0019
#     Feature 5594: weight=0.0002
#
# Class 13: 12 non-zero features (sorted by weight, positives first)
#     Feature 5676: weight=0.0079
#     Feature 6024: weight=0.0045
#     Feature 2505: weight=0.0040
#     Feature 2614: weight=0.0024
#     Feature 1543: weight=0.0018
#     Feature 2310: weight=0.0016
#     Feature 2621: weight=0.0011
#     Feature 4955: weight=0.0008
#     Feature 1971: weight=0.0007
#     Feature 483: weight=0.0002
#     Feature 4458: weight=0.0001
#     Feature 1611: weight=0.0001
#
# Class 14: 18 non-zero features (sorted by weight, positives first)
#     Feature 1783: weight=0.0080
#     Feature 2808: weight=0.0054
#     Feature 349: weight=0.0038
#     Feature 5994: weight=0.0031
#     Feature 1971: weight=0.0030
#     Feature 1502: weight=0.0019
#     Feature 4955: weight=0.0018
#     Feature 2614: weight=0.0017
#     Feature 1611: weight=0.0016
#     Feature 5594: weight=0.0015
#     Feature 3504: weight=0.0011
#     Feature 4984: weight=0.0009
#     Feature 854: weight=0.0008
#     Feature 3304: weight=0.0006
#     Feature 1758: weight=0.0004
#     Feature 579: weight=0.0004
#     Feature 3839: weight=0.0003
#     Feature 1784: weight=0.0002
#
# Class 15: 47 non-zero features (sorted by weight, positives first)
#     Feature 3979: weight=0.0073
#     Feature 5495: weight=0.0064
#     Feature 4984: weight=0.0048
#     Feature 4955: weight=0.0044
#     Feature 44: weight=0.0038
#     Feature 1746: weight=0.0036
#     Feature 2640: weight=0.0034
#     Feature 4067: weight=0.0030
#     Feature 5594: weight=0.0029
#     Feature 1971: weight=0.0029
#     Feature 3304: weight=0.0028
#     Feature 3839: weight=0.0026
#     Feature 1317: weight=0.0024
#     Feature 135: weight=0.0023
#     Feature 1611: weight=0.0021
#     Feature 132: weight=0.0021
#     Feature 5994: weight=0.0018
#     Feature 1758: weight=0.0017
#     Feature 5357: weight=0.0017
#     Feature 2505: weight=0.0016
#     Feature 2614: weight=0.0016
#     Feature 2621: weight=0.0014
#     Feature 3401: weight=0.0011
#     Feature 5797: weight=0.0011
#     Feature 6085: weight=0.0007
#     Feature 483: weight=0.0007
#     Feature 2647: weight=0.0006
#     Feature 2262: weight=0.0006
#     Feature 1555: weight=0.0006
#     Feature 3963: weight=0.0006
#     Feature 5472: weight=0.0005
#     Feature 878: weight=0.0005
#     Feature 1641: weight=0.0004
#     Feature 960: weight=0.0004
#     Feature 1524: weight=0.0004
#     Feature 3821: weight=0.0003
#     Feature 2077: weight=0.0003
#     Feature 4373: weight=0.0003
#     Feature 3639: weight=0.0002
#     Feature 854: weight=0.0002
#     Feature 4017: weight=0.0002
#     Feature 5721: weight=0.0002
#     Feature 3076: weight=0.0001
#     Feature 2485: weight=0.0001
#     Feature 2310: weight=0.0001
#     Feature 4967: weight=0.0001
#     Feature 1798: weight=0.0001
#
# Class 16: 11 non-zero features (sorted by weight, positives first)
#     Feature 44: weight=0.0045
#     Feature 132: weight=0.0041
#     Feature 1611: weight=0.0019
#     Feature 5405: weight=0.0015
#     Feature 1971: weight=0.0012
#     Feature 3304: weight=0.0010
#     Feature 3821: weight=0.0009
#     Feature 1798: weight=0.0008
#     Feature 5495: weight=0.0003
#     Feature 5594: weight=0.0003
#     Feature 5973: weight=0.0001
#
# Class 17: 14 non-zero features (sorted by weight, positives first)
#     Feature 4201: weight=0.0100
#     Feature 1100: weight=0.0053
#     Feature 1971: weight=0.0029
#     Feature 5594: weight=0.0024
#     Feature 1611: weight=0.0024
#     Feature 854: weight=0.0022
#     Feature 1317: weight=0.0015
#     Feature 210: weight=0.0012
#     Feature 4154: weight=0.0012
#     Feature 2077: weight=0.0011
#     Feature 5123: weight=0.0007
#     Feature 2614: weight=0.0006
#     Feature 2310: weight=0.0005
#     Feature 3304: weight=0.0005
#
# Class 18: 17 non-zero features (sorted by weight, positives first)
#     Feature 1037: weight=0.0075
#     Feature 4409: weight=0.0052
#     Feature 1575: weight=0.0046
#     Feature 5049: weight=0.0044
#     Feature 1971: weight=0.0025
#     Feature 1543: weight=0.0024
#     Feature 3271: weight=0.0019
#     Feature 5594: weight=0.0015
#     Feature 2621: weight=0.0014
#     Feature 573: weight=0.0010
#     Feature 210: weight=0.0010
#     Feature 4358: weight=0.0008
#     Feature 3963: weight=0.0005
#     Feature 2006: weight=0.0004
#     Feature 352: weight=0.0004
#     Feature 1945: weight=0.0002
#     Feature 3478: weight=0.0001
#
# Class 19: 9 non-zero features (sorted by weight, positives first)
#     Feature 1537: weight=0.0030
#     Feature 352: weight=0.0027
#     Feature 4391: weight=0.0021
#     Feature 5797: weight=0.0019
#     Feature 5594: weight=0.0016
#     Feature 1575: weight=0.0012
#     Feature 3304: weight=0.0006
#     Feature 1971: weight=0.0005
#     Feature 1162: weight=0.0003
#
# Class 20: 5 non-zero features (sorted by weight, positives first)
#     Feature 6039: weight=0.0052
#     Feature 1971: weight=0.0017
#     Feature 4458: weight=0.0013
#     Feature 5239: weight=0.0010
#     Feature 1611: weight=0.0005
#
# Class 21: 10 non-zero features (sorted by weight, positives first)
#     Feature 4954: weight=0.0059
#     Feature 4749: weight=0.0029
#     Feature 5594: weight=0.0024
#     Feature 473: weight=0.0023
#     Feature 5797: weight=0.0023
#     Feature 2621: weight=0.0020
#     Feature 3304: weight=0.0013
#     Feature 1555: weight=0.0013
#     Feature 1971: weight=0.0012
#     Feature 1524: weight=0.0011
#
# Class 22: 10 non-zero features (sorted by weight, positives first)
#     Feature 323: weight=0.0051
#     Feature 97: weight=0.0041
#     Feature 1543: weight=0.0040
#     Feature 1971: weight=0.0040
#     Feature 3304: weight=0.0033
#     Feature 5594: weight=0.0027
#     Feature 1611: weight=0.0026
#     Feature 1555: weight=0.0004
#     Feature 1317: weight=0.0002
#     Feature 1758: weight=0.0001
#
# Class 23: 27 non-zero features (sorted by weight, positives first)
#     Feature 2666: weight=0.0068
#     Feature 1511: weight=0.0053
#     Feature 5868: weight=0.0046
#     Feature 2717: weight=0.0043
#     Feature 4967: weight=0.0037
#     Feature 1543: weight=0.0030
#     Feature 1971: weight=0.0030
#     Feature 4955: weight=0.0026
#     Feature 1555: weight=0.0025
#     Feature 3304: weight=0.0024
#     Feature 3652: weight=0.0023
#     Feature 5594: weight=0.0022
#     Feature 323: weight=0.0021
#     Feature 5797: weight=0.0019
#     Feature 2484: weight=0.0016
#     Feature 1758: weight=0.0008
#     Feature 2077: weight=0.0007
#     Feature 1611: weight=0.0007
#     Feature 97: weight=0.0007
#     Feature 3963: weight=0.0006
#     Feature 1524: weight=0.0005
#     Feature 2621: weight=0.0004
#     Feature 483: weight=0.0003
#     Feature 1947: weight=0.0002
#     Feature 5360: weight=0.0001
#     Feature 2986: weight=0.0001
#     Feature 2006: weight=0.0001
#
# Class 24: 11 non-zero features (sorted by weight, positives first)
#     Feature 1498: weight=0.0136
#     Feature 3639: weight=0.0057
#     Feature 1543: weight=0.0052
#     Feature 3304: weight=0.0030
#     Feature 5797: weight=0.0022
#     Feature 4208: weight=0.0013
#     Feature 1611: weight=0.0013
#     Feature 2360: weight=0.0011
#     Feature 4614: weight=0.0007
#     Feature 5594: weight=0.0003
#     Feature 4098: weight=0.0002
#
# Class 25: 6 non-zero features (sorted by weight, positives first)
#     Feature 549: weight=0.0025
#     Feature 1971: weight=0.0022
#     Feature 2360: weight=0.0016
#     Feature 3304: weight=0.0014
#     Feature 1555: weight=0.0010
#     Feature 1947: weight=0.0004
#
# Class 26: 24 non-zero features (sorted by weight, positives first)
#     Feature 573: weight=0.0087
#     Feature 2887: weight=0.0055
#     Feature 1428: weight=0.0042
#     Feature 5797: weight=0.0026
#     Feature 1037: weight=0.0025
#     Feature 3271: weight=0.0025
#     Feature 3304: weight=0.0024
#     Feature 1611: weight=0.0017
#     Feature 4955: weight=0.0016
#     Feature 210: weight=0.0016
#     Feature 1317: weight=0.0014
#     Feature 4458: weight=0.0013
#     Feature 1971: weight=0.0013
#     Feature 1746: weight=0.0008
#     Feature 6039: weight=0.0007
#     Feature 3963: weight=0.0006
#     Feature 354: weight=0.0004
#     Feature 4409: weight=0.0003
#     Feature 1758: weight=0.0001
#     Feature 2621: weight=0.0001
#     Feature 5594: weight=0.0001
#     Feature 3478: weight=0.0001
#     Feature 1353: weight=0.0001
#     Feature 1945: weight=0.0001
#
# Class 27: 8 non-zero features (sorted by weight, positives first)
#     Feature 1945: weight=0.0048
#     Feature 5614: weight=0.0040
#     Feature 2077: weight=0.0022
#     Feature 1971: weight=0.0020
#     Feature 3304: weight=0.0013
#     Feature 4955: weight=0.0010
#     Feature 1611: weight=0.0002
#     Feature 5797: weight=0.0002
#
# Class 28: 13 non-zero features (sorted by weight, positives first)
#     Feature 1037: weight=0.0039
#     Feature 2105: weight=0.0030
#     Feature 4816: weight=0.0029
#     Feature 3304: weight=0.0023
#     Feature 1971: weight=0.0010
#     Feature 3394: weight=0.0007
#     Feature 1611: weight=0.0006
#     Feature 5797: weight=0.0006
#     Feature 354: weight=0.0003
#     Feature 573: weight=0.0003
#     Feature 3271: weight=0.0002
#     Feature 1543: weight=0.0002
#     Feature 1758: weight=0.0001
#
# Class 29: 6 non-zero features (sorted by weight, positives first)
#     Feature 354: weight=0.0035
#     Feature 3271: weight=0.0021
#     Feature 3304: weight=0.0014
#     Feature 1971: weight=0.0010
#     Feature 3478: weight=0.0007
#     Feature 5594: weight=0.0005
#
# Class 30: 0 non-zero features (sorted by weight, positives first)
#
# Class 31: 5 non-zero features (sorted by weight, positives first)
#     Feature 505: weight=0.0035
#     Feature 1206: weight=0.0025
#     Feature 1971: weight=0.0018
#     Feature 5797: weight=0.0011
#     Feature 1611: weight=0.0009
#
# Class 32: 5 non-zero features (sorted by weight, positives first)
#     Feature 5252: weight=0.0028
#     Feature 3245: weight=0.0027
#     Feature 1971: weight=0.0026
#     Feature 1611: weight=0.0002
#     Feature 2262: weight=0.0001
#
# Class 33: 8 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0025
#     Feature 5869: weight=0.0015
#     Feature 3625: weight=0.0011
#     Feature 1611: weight=0.0007
#     Feature 210: weight=0.0003
#     Feature 2791: weight=0.0002
#     Feature 683: weight=0.0001
#     Feature 2262: weight=0.0001
#
# Class 34: 2 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0027
#     Feature 1611: weight=0.0002
#
# Class 35: 0 non-zero features (sorted by weight, positives first)
#
# Class 36: 5 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0026
#     Feature 4160: weight=0.0012
#     Feature 3304: weight=0.0003
#     Feature 2004: weight=0.0003
#     Feature 2353: weight=0.0001
#
# Class 37: 4 non-zero features (sorted by weight, positives first)
#     Feature 2791: weight=0.0035
#     Feature 3262: weight=0.0024
#     Feature 1971: weight=0.0017
#     Feature 3304: weight=0.0001
#
# Class 38: 4 non-zero features (sorted by weight, positives first)
#     Feature 3304: weight=0.0017
#     Feature 4123: weight=0.0015
#     Feature 1971: weight=0.0012
#     Feature 3941: weight=0.0003
#
# Class 39: 16 non-zero features (sorted by weight, positives first)
#     Feature 2938: weight=0.0060
#     Feature 1317: weight=0.0028
#     Feature 3304: weight=0.0022
#     Feature 5797: weight=0.0016
#     Feature 1611: weight=0.0015
#     Feature 5496: weight=0.0014
#     Feature 5869: weight=0.0010
#     Feature 5594: weight=0.0008
#     Feature 1543: weight=0.0007
#     Feature 4337: weight=0.0007
#     Feature 1971: weight=0.0007
#     Feature 2051: weight=0.0005
#     Feature 2262: weight=0.0004
#     Feature 6095: weight=0.0003
#     Feature 928: weight=0.0002
#     Feature 210: weight=0.0002
#
# Class 40: 5 non-zero features (sorted by weight, positives first)
#     Feature 4444: weight=0.0053
#     Feature 3304: weight=0.0032
#     Feature 1424: weight=0.0010
#     Feature 2238: weight=0.0002
#     Feature 1971: weight=0.0001
#
# Class 41: 0 non-zero features (sorted by weight, positives first)
#
# Class 42: 7 non-zero features (sorted by weight, positives first)
#     Feature 1428: weight=0.0084
#     Feature 5797: weight=0.0031
#     Feature 3304: weight=0.0011
#     Feature 5594: weight=0.0005
#     Feature 2004: weight=0.0005
#     Feature 5076: weight=0.0004
#     Feature 1971: weight=0.0003
#
# Class 43: 10 non-zero features (sorted by weight, positives first)
#     Feature 3744: weight=0.0042
#     Feature 5797: weight=0.0023
#     Feature 1971: weight=0.0017
#     Feature 1543: weight=0.0016
#     Feature 4908: weight=0.0015
#     Feature 3304: weight=0.0007
#     Feature 928: weight=0.0004
#     Feature 3262: weight=0.0002
#     Feature 5869: weight=0.0002
#     Feature 2262: weight=0.0002
#
# Class 44: 3 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0027
#     Feature 1969: weight=0.0015
#     Feature 4541: weight=0.0009
#
# Class 45: 10 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0022
#     Feature 3540: weight=0.0019
#     Feature 3304: weight=0.0014
#     Feature 1758: weight=0.0011
#     Feature 5869: weight=0.0011
#     Feature 2051: weight=0.0007
#     Feature 3744: weight=0.0004
#     Feature 5496: weight=0.0003
#     Feature 1611: weight=0.0001
#     Feature 3394: weight=0.0001
#
# Class 46: 26 non-zero features (sorted by weight, positives first)
#     Feature 2694: weight=0.0117
#     Feature 1513: weight=0.0116
#     Feature 5594: weight=0.0047
#     Feature 5360: weight=0.0038
#     Feature 5721: weight=0.0036
#     Feature 483: weight=0.0031
#     Feature 4955: weight=0.0031
#     Feature 3010: weight=0.0026
#     Feature 4967: weight=0.0024
#     Feature 4458: weight=0.0018
#     Feature 1317: weight=0.0018
#     Feature 1611: weight=0.0017
#     Feature 1705: weight=0.0017
#     Feature 5105: weight=0.0012
#     Feature 2621: weight=0.0011
#     Feature 5865: weight=0.0011
#     Feature 1543: weight=0.0008
#     Feature 2262: weight=0.0007
#     Feature 2310: weight=0.0007
#     Feature 2998: weight=0.0003
#     Feature 1971: weight=0.0002
#     Feature 3304: weight=0.0001
#     Feature 2184: weight=0.0001
#     Feature 1138: weight=0.0001
#     Feature 3404: weight=0.0001
#     Feature 5480: weight=0.0001
#
# Class 47: 14 non-zero features (sorted by weight, positives first)
#     Feature 3825: weight=0.0087
#     Feature 1611: weight=0.0029
#     Feature 1138: weight=0.0026
#     Feature 4458: weight=0.0022
#     Feature 5797: weight=0.0015
#     Feature 5594: weight=0.0010
#     Feature 1971: weight=0.0009
#     Feature 2614: weight=0.0007
#     Feature 2621: weight=0.0006
#     Feature 2815: weight=0.0005
#     Feature 3304: weight=0.0005
#     Feature 2571: weight=0.0004
#     Feature 3639: weight=0.0003
#     Feature 4632: weight=0.0001
#
# Class 48: 8 non-zero features (sorted by weight, positives first)
#     Feature 3645: weight=0.0074
#     Feature 3010: weight=0.0059
#     Feature 1381: weight=0.0051
#     Feature 2223: weight=0.0050
#     Feature 2526: weight=0.0044
#     Feature 6095: weight=0.0026
#     Feature 1971: weight=0.0017
#     Feature 3304: weight=0.0007
#
# Class 49: 51 non-zero features (sorted by weight, positives first)
#     Feature 604: weight=0.0156
#     Feature 2329: weight=0.0128
#     Feature 2614: weight=0.0100
#     Feature 2223: weight=0.0089
#     Feature 4458: weight=0.0082
#     Feature 6095: weight=0.0080
#     Feature 2640: weight=0.0077
#     Feature 3625: weight=0.0076
#     Feature 1138: weight=0.0065
#     Feature 4363: weight=0.0047
#     Feature 3639: weight=0.0046
#     Feature 6081: weight=0.0045
#     Feature 5480: weight=0.0043
#     Feature 483: weight=0.0042
#     Feature 5105: weight=0.0041
#     Feature 2323: weight=0.0040
#     Feature 5594: weight=0.0035
#     Feature 1513: weight=0.0030
#     Feature 1524: weight=0.0029
#     Feature 1701: weight=0.0027
#     Feature 633: weight=0.0024
#     Feature 1953: weight=0.0023
#     Feature 1705: weight=0.0022
#     Feature 2621: weight=0.0022
#     Feature 1611: weight=0.0021
#     Feature 210: weight=0.0020
#     Feature 5968: weight=0.0019
#     Feature 3304: weight=0.0019
#     Feature 5655: weight=0.0018
#     Feature 2647: weight=0.0016
#     Feature 5385: weight=0.0014
#     Feature 1758: weight=0.0013
#     Feature 3084: weight=0.0011
#     Feature 4154: weight=0.0011
#     Feature 1555: weight=0.0010
#     Feature 4588: weight=0.0010
#     Feature 1971: weight=0.0009
#     Feature 3115: weight=0.0009
#     Feature 2303: weight=0.0009
#     Feature 4547: weight=0.0007
#     Feature 2262: weight=0.0006
#     Feature 4967: weight=0.0006
#     Feature 4955: weight=0.0004
#     Feature 4509: weight=0.0004
#     Feature 4757: weight=0.0004
#     Feature 5797: weight=0.0004
#     Feature 5721: weight=0.0004
#     Feature 620: weight=0.0004
#     Feature 2526: weight=0.0003
#     Feature 4435: weight=0.0002
#     Feature 3395: weight=0.0001
#
# Class 50: 1 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0010
#
# Class 51: 21 non-zero features (sorted by weight, positives first)
#     Feature 3010: weight=0.0108
#     Feature 5360: weight=0.0054
#     Feature 5797: weight=0.0053
#     Feature 3115: weight=0.0045
#     Feature 1611: weight=0.0041
#     Feature 4458: weight=0.0040
#     Feature 1971: weight=0.0033
#     Feature 4632: weight=0.0032
#     Feature 1758: weight=0.0027
#     Feature 5974: weight=0.0023
#     Feature 2647: weight=0.0016
#     Feature 5865: weight=0.0014
#     Feature 5105: weight=0.0007
#     Feature 1555: weight=0.0006
#     Feature 3639: weight=0.0003
#     Feature 483: weight=0.0003
#     Feature 3304: weight=0.0002
#     Feature 1138: weight=0.0002
#     Feature 604: weight=0.0001
#     Feature 2621: weight=0.0001
#     Feature 5594: weight=0.0001
#
# Class 52: 8 non-zero features (sorted by weight, positives first)
#     Feature 1701: weight=0.0051
#     Feature 4747: weight=0.0049
#     Feature 3304: weight=0.0016
#     Feature 1611: weight=0.0015
#     Feature 1971: weight=0.0010
#     Feature 183: weight=0.0003
#     Feature 1543: weight=0.0002
#     Feature 5594: weight=0.0001
#
# Class 53: 13 non-zero features (sorted by weight, positives first)
#     Feature 5480: weight=0.0089
#     Feature 4458: weight=0.0058
#     Feature 2223: weight=0.0045
#     Feature 3538: weight=0.0031
#     Feature 183: weight=0.0029
#     Feature 1543: weight=0.0018
#     Feature 1611: weight=0.0016
#     Feature 2303: weight=0.0013
#     Feature 1971: weight=0.0009
#     Feature 5594: weight=0.0007
#     Feature 1701: weight=0.0004
#     Feature 3304: weight=0.0002
#     Feature 1758: weight=0.0001
#
# Class 54: 27 non-zero features (sorted by weight, positives first)
#     Feature 3538: weight=0.0119
#     Feature 1138: weight=0.0118
#     Feature 4435: weight=0.0068
#     Feature 4458: weight=0.0052
#     Feature 604: weight=0.0051
#     Feature 5594: weight=0.0047
#     Feature 5360: weight=0.0029
#     Feature 2614: weight=0.0028
#     Feature 4955: weight=0.0024
#     Feature 3304: weight=0.0024
#     Feature 1746: weight=0.0024
#     Feature 5797: weight=0.0023
#     Feature 3115: weight=0.0019
#     Feature 1513: weight=0.0016
#     Feature 1758: weight=0.0009
#     Feature 4632: weight=0.0009
#     Feature 1555: weight=0.0009
#     Feature 6053: weight=0.0007
#     Feature 5974: weight=0.0007
#     Feature 1611: weight=0.0005
#     Feature 483: weight=0.0005
#     Feature 2621: weight=0.0004
#     Feature 3010: weight=0.0002
#     Feature 3639: weight=0.0001
#     Feature 2262: weight=0.0001
#     Feature 2772: weight=0.0001
#     Feature 183: weight=0.0001
#
# Class 55: 13 non-zero features (sorted by weight, positives first)
#     Feature 1582: weight=0.0076
#     Feature 2183: weight=0.0034
#     Feature 1971: weight=0.0016
#     Feature 1611: weight=0.0010
#     Feature 3304: weight=0.0010
#     Feature 6009: weight=0.0009
#     Feature 5994: weight=0.0006
#     Feature 854: weight=0.0004
#     Feature 5594: weight=0.0003
#     Feature 5797: weight=0.0002
#     Feature 3478: weight=0.0001
#     Feature 2808: weight=0.0001
#     Feature 1543: weight=0.0001
#
# Class 56: 10 non-zero features (sorted by weight, positives first)
#     Feature 520: weight=0.0051
#     Feature 4858: weight=0.0048
#     Feature 1971: weight=0.0018
#     Feature 2310: weight=0.0015
#     Feature 2184: weight=0.0014
#     Feature 5594: weight=0.0010
#     Feature 3304: weight=0.0009
#     Feature 2851: weight=0.0007
#     Feature 210: weight=0.0006
#     Feature 1611: weight=0.0005
#
# Class 57: 19 non-zero features (sorted by weight, positives first)
#     Feature 5168: weight=0.0063
#     Feature 854: weight=0.0062
#     Feature 1582: weight=0.0060
#     Feature 6009: weight=0.0041
#     Feature 3304: weight=0.0017
#     Feature 1611: weight=0.0015
#     Feature 1543: weight=0.0013
#     Feature 2640: weight=0.0012
#     Feature 4858: weight=0.0011
#     Feature 5797: weight=0.0010
#     Feature 1746: weight=0.0010
#     Feature 5974: weight=0.0007
#     Feature 1758: weight=0.0007
#     Feature 6107: weight=0.0004
#     Feature 2262: weight=0.0004
#     Feature 2006: weight=0.0003
#     Feature 5594: weight=0.0001
#     Feature 1971: weight=0.0001
#     Feature 3625: weight=0.0001
#
# Class 58: 7 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0033
#     Feature 4822: weight=0.0014
#     Feature 1611: weight=0.0012
#     Feature 4017: weight=0.0011
#     Feature 1835: weight=0.0007
#     Feature 5594: weight=0.0001
#     Feature 3478: weight=0.0001
#
# Class 59: 7 non-zero features (sorted by weight, positives first)
#     Feature 2827: weight=0.0072
#     Feature 1543: weight=0.0027
#     Feature 1611: weight=0.0021
#     Feature 4824: weight=0.0018
#     Feature 1971: weight=0.0012
#     Feature 3304: weight=0.0006
#     Feature 1555: weight=0.0001
#
# Class 60: 7 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0025
#     Feature 1262: weight=0.0025
#     Feature 5731: weight=0.0014
#     Feature 1611: weight=0.0007
#     Feature 2326: weight=0.0003
#     Feature 3009: weight=0.0002
#     Feature 4649: weight=0.0001
#
# Class 61: 1 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0019
#
# Class 62: 5 non-zero features (sorted by weight, positives first)
#     Feature 579: weight=0.0040
#     Feature 2310: weight=0.0020
#     Feature 1971: weight=0.0019
#     Feature 1611: weight=0.0017
#     Feature 5594: weight=0.0002
#
# Class 63: 8 non-zero features (sorted by weight, positives first)
#     Feature 2383: weight=0.0031
#     Feature 3304: weight=0.0025
#     Feature 1611: weight=0.0009
#     Feature 5861: weight=0.0006
#     Feature 4955: weight=0.0003
#     Feature 1971: weight=0.0001
#     Feature 2283: weight=0.0001
#     Feature 728: weight=0.0001
#
# Class 64: 9 non-zero features (sorted by weight, positives first)
#     Feature 5472: weight=0.0043
#     Feature 2685: weight=0.0040
#     Feature 5079: weight=0.0034
#     Feature 1971: weight=0.0020
#     Feature 5594: weight=0.0015
#     Feature 1611: weight=0.0008
#     Feature 3723: weight=0.0003
#     Feature 3304: weight=0.0002
#     Feature 1758: weight=0.0002
#
# Class 65: 11 non-zero features (sorted by weight, positives first)
#     Feature 6085: weight=0.0122
#     Feature 2077: weight=0.0043
#     Feature 1611: weight=0.0031
#     Feature 5594: weight=0.0029
#     Feature 4154: weight=0.0024
#     Feature 1971: weight=0.0010
#     Feature 4967: weight=0.0010
#     Feature 3304: weight=0.0009
#     Feature 210: weight=0.0007
#     Feature 2310: weight=0.0005
#     Feature 1555: weight=0.0003
#
# Class 66: 13 non-zero features (sorted by weight, positives first)
#     Feature 5079: weight=0.0051
#     Feature 3031: weight=0.0035
#     Feature 1647: weight=0.0027
#     Feature 5594: weight=0.0026
#     Feature 1971: weight=0.0011
#     Feature 4955: weight=0.0011
#     Feature 1611: weight=0.0009
#     Feature 1641: weight=0.0008
#     Feature 1672: weight=0.0006
#     Feature 5472: weight=0.0003
#     Feature 3723: weight=0.0003
#     Feature 210: weight=0.0003
#     Feature 3304: weight=0.0002
#
# Class 67: 6 non-zero features (sorted by weight, positives first)
#     Feature 3585: weight=0.0056
#     Feature 3304: weight=0.0029
#     Feature 1971: weight=0.0006
#     Feature 5994: weight=0.0005
#     Feature 483: weight=0.0002
#     Feature 1746: weight=0.0001
#
# Class 68: 3 non-zero features (sorted by weight, positives first)
#     Feature 4971: weight=0.0049
#     Feature 1971: weight=0.0022
#     Feature 1611: weight=0.0008
#
# Class 69: 12 non-zero features (sorted by weight, positives first)
#     Feature 1921: weight=0.0090
#     Feature 2640: weight=0.0026
#     Feature 3304: weight=0.0025
#     Feature 5797: weight=0.0024
#     Feature 1971: weight=0.0021
#     Feature 3009: weight=0.0016
#     Feature 2203: weight=0.0013
#     Feature 1602: weight=0.0008
#     Feature 2381: weight=0.0008
#     Feature 2077: weight=0.0008
#     Feature 2621: weight=0.0001
#     Feature 1611: weight=0.0001
#
# Class 70: 5 non-zero features (sorted by weight, positives first)
#     Feature 1531: weight=0.0030
#     Feature 1971: weight=0.0017
#     Feature 3304: weight=0.0009
#     Feature 1611: weight=0.0008
#     Feature 1184: weight=0.0007
#
# Class 71: 3 non-zero features (sorted by weight, positives first)
#     Feature 255: weight=0.0098
#     Feature 1611: weight=0.0027
#     Feature 1971: weight=0.0001
#
# Class 72: 10 non-zero features (sorted by weight, positives first)
#     Feature 5757: weight=0.0077
#     Feature 4703: weight=0.0066
#     Feature 5594: weight=0.0018
#     Feature 1971: weight=0.0016
#     Feature 2262: weight=0.0015
#     Feature 2647: weight=0.0010
#     Feature 5797: weight=0.0010
#     Feature 1611: weight=0.0005
#     Feature 2216: weight=0.0001
#     Feature 3304: weight=0.0001
#
# Class 73: 7 non-zero features (sorted by weight, positives first)
#     Feature 5983: weight=0.0048
#     Feature 1971: weight=0.0027
#     Feature 5189: weight=0.0023
#     Feature 5385: weight=0.0016
#     Feature 4458: weight=0.0012
#     Feature 1611: weight=0.0005
#     Feature 6081: weight=0.0004
#
# Class 74: 0 non-zero features (sorted by weight, positives first)
#
# Class 75: 60 non-zero features (sorted by weight, positives first)
#     Feature 3394: weight=0.0103
#     Feature 2614: weight=0.0066
#     Feature 3734: weight=0.0059
#     Feature 1138: weight=0.0057
#     Feature 928: weight=0.0057
#     Feature 1746: weight=0.0047
#     Feature 2262: weight=0.0044
#     Feature 3477: weight=0.0041
#     Feature 3639: weight=0.0036
#     Feature 914: weight=0.0035
#     Feature 6053: weight=0.0034
#     Feature 1037: weight=0.0032
#     Feature 3571: weight=0.0032
#     Feature 2647: weight=0.0031
#     Feature 4653: weight=0.0031
#     Feature 1672: weight=0.0030
#     Feature 5178: weight=0.0029
#     Feature 2621: weight=0.0027
#     Feature 1535: weight=0.0027
#     Feature 697: weight=0.0027
#     Feature 483: weight=0.0023
#     Feature 4955: weight=0.0022
#     Feature 1758: weight=0.0021
#     Feature 4966: weight=0.0021
#     Feature 5594: weight=0.0020
#     Feature 801: weight=0.0020
#     Feature 2694: weight=0.0020
#     Feature 210: weight=0.0020
#     Feature 5614: weight=0.0018
#     Feature 3401: weight=0.0017
#     Feature 484: weight=0.0016
#     Feature 2998: weight=0.0016
#     Feature 4458: weight=0.0015
#     Feature 3540: weight=0.0014
#     Feature 5360: weight=0.0014
#     Feature 3883: weight=0.0013
#     Feature 1513: weight=0.0012
#     Feature 5797: weight=0.0012
#     Feature 4154: weight=0.0010
#     Feature 4967: weight=0.0010
#     Feature 3009: weight=0.0010
#     Feature 1317: weight=0.0009
#     Feature 1971: weight=0.0008
#     Feature 1162: weight=0.0007
#     Feature 2640: weight=0.0007
#     Feature 4703: weight=0.0007
#     Feature 3538: weight=0.0007
#     Feature 3304: weight=0.0007
#     Feature 1163: weight=0.0006
#     Feature 5757: weight=0.0005
#     Feature 1524: weight=0.0003
#     Feature 2006: weight=0.0003
#     Feature 5385: weight=0.0003
#     Feature 1611: weight=0.0003
#     Feature 1701: weight=0.0002
#     Feature 2323: weight=0.0002
#     Feature 2310: weight=0.0001
#     Feature 3963: weight=0.0001
#     Feature 1543: weight=0.0001
#     Feature 1511: weight=0.0001
#
# Class 76: 15 non-zero features (sorted by weight, positives first)
#     Feature 4347: weight=0.0097
#     Feature 1065: weight=0.0093
#     Feature 1611: weight=0.0055
#     Feature 5797: weight=0.0046
#     Feature 1971: weight=0.0037
#     Feature 1543: weight=0.0035
#     Feature 3304: weight=0.0020
#     Feature 6113: weight=0.0019
#     Feature 483: weight=0.0018
#     Feature 3639: weight=0.0016
#     Feature 6085: weight=0.0013
#     Feature 210: weight=0.0013
#     Feature 801: weight=0.0004
#     Feature 5594: weight=0.0004
#     Feature 1002: weight=0.0001
#
# Class 77: 11 non-zero features (sorted by weight, positives first)
#     Feature 3423: weight=0.0079
#     Feature 5594: weight=0.0033
#     Feature 210: weight=0.0027
#     Feature 5797: weight=0.0019
#     Feature 6081: weight=0.0014
#     Feature 1079: weight=0.0008
#     Feature 483: weight=0.0007
#     Feature 1611: weight=0.0005
#     Feature 2982: weight=0.0005
#     Feature 1971: weight=0.0005
#     Feature 2621: weight=0.0002
#
# Class 78: 4 non-zero features (sorted by weight, positives first)
#     Feature 1971: weight=0.0028
#     Feature 5328: weight=0.0014
#     Feature 1535: weight=0.0005
#     Feature 2338: weight=0.0001
#
# Class 79: 12 non-zero features (sorted by weight, positives first)
#     Feature 4536: weight=0.0039
#     Feature 2957: weight=0.0037
#     Feature 5797: weight=0.0034
#     Feature 1611: weight=0.0014
#     Feature 2642: weight=0.0014
#     Feature 381: weight=0.0009
#     Feature 4807: weight=0.0008
#     Feature 2614: weight=0.0008
#     Feature 5733: weight=0.0005
#     Feature 4955: weight=0.0005
#     Feature 1971: weight=0.0003
#     Feature 3304: weight=0.0002
#
# Class 80: 22 non-zero features (sorted by weight, positives first)
#     Feature 5385: weight=0.0104
#     Feature 6081: weight=0.0092
#     Feature 5594: weight=0.0042
#     Feature 5974: weight=0.0035
#     Feature 2262: weight=0.0034
#     Feature 483: weight=0.0032
#     Feature 1611: weight=0.0032
#     Feature 2077: weight=0.0030
#     Feature 6113: weight=0.0025
#     Feature 5797: weight=0.0021
#     Feature 4955: weight=0.0018
#     Feature 3478: weight=0.0018
#     Feature 1543: weight=0.0015
#     Feature 4347: weight=0.0014
#     Feature 4458: weight=0.0011
#     Feature 1758: weight=0.0011
#     Feature 5189: weight=0.0007
#     Feature 5733: weight=0.0005
#     Feature 1641: weight=0.0005
#     Feature 5259: weight=0.0005
#     Feature 5983: weight=0.0002
#     Feature 914: weight=0.0001
#
# Class 81: 11 non-zero features (sorted by weight, positives first)
#     Feature 1690: weight=0.0079
#     Feature 1138: weight=0.0048
#     Feature 1971: weight=0.0038
#     Feature 1543: weight=0.0030
#     Feature 1611: weight=0.0025
#     Feature 4398: weight=0.0024
#     Feature 1163: weight=0.0019
#     Feature 2815: weight=0.0010
#     Feature 67: weight=0.0007
#     Feature 210: weight=0.0004
#     Feature 3304: weight=0.0001
#
# Class 82: 11 non-zero features (sorted by weight, positives first)
#     Feature 2815: weight=0.0031
#     Feature 3304: weight=0.0030
#     Feature 67: weight=0.0026
#     Feature 1611: weight=0.0017
#     Feature 5797: weight=0.0013
#     Feature 4458: weight=0.0012
#     Feature 4955: weight=0.0007
#     Feature 2323: weight=0.0006
#     Feature 5594: weight=0.0004
#     Feature 2571: weight=0.0002
#     Feature 1971: weight=0.0002
#
# Class 83: 4 non-zero features (sorted by weight, positives first)
#     Feature 3395: weight=0.0052
#     Feature 620: weight=0.0039
#     Feature 1971: weight=0.0017
#     Feature 5360: weight=0.0014
#
# Class 84: 10 non-zero features (sorted by weight, positives first)
#     Feature 3304: weight=0.0084
#     Feature 3047: weight=0.0032
#     Feature 1971: weight=0.0026
#     Feature 5797: weight=0.0024
#     Feature 2621: weight=0.0019
#     Feature 5259: weight=0.0016
#     Feature 1611: weight=0.0005
#     Feature 3395: weight=0.0005
#     Feature 801: weight=0.0002
#     Feature 1758: weight=0.0002
#
# Class 85: 4 non-zero features (sorted by weight, positives first)
#     Feature 1254: weight=0.0054
#     Feature 1611: weight=0.0019
#     Feature 1971: weight=0.0014
#     Feature 5797: weight=0.0010
#
# Class 86: 7 non-zero features (sorted by weight, positives first)
#     Feature 3198: weight=0.0023
#     Feature 1611: weight=0.0016
#     Feature 3304: weight=0.0014
#     Feature 4955: weight=0.0005
#     Feature 4959: weight=0.0005
#     Feature 5594: weight=0.0003
#     Feature 1758: weight=0.0001
#
# Class 87: 15 non-zero features (sorted by weight, positives first)
#     Feature 522: weight=0.0119
#     Feature 3478: weight=0.0035
#     Feature 4955: weight=0.0025
#     Feature 5594: weight=0.0018
#     Feature 5797: weight=0.0015
#     Feature 1611: weight=0.0009
#     Feature 1971: weight=0.0008
#     Feature 1758: weight=0.0008
#     Feature 483: weight=0.0007
#     Feature 1543: weight=0.0004
#     Feature 3304: weight=0.0003
#     Feature 1641: weight=0.0001
#     Feature 2295: weight=0.0001
#     Feature 4373: weight=0.0001
#     Feature 135: weight=0.0001
#
# Class 88: 6 non-zero features (sorted by weight, positives first)
#     Feature 4220: weight=0.0032
#     Feature 1971: weight=0.0030
#     Feature 3304: weight=0.0014
#     Feature 3783: weight=0.0014
#     Feature 1983: weight=0.0010
#     Feature 5594: weight=0.0003
#
# Class 89: 9 non-zero features (sorted by weight, positives first)
#     Feature 728: weight=0.0110
#     Feature 1971: weight=0.0031
#     Feature 1611: weight=0.0026
#     Feature 4086: weight=0.0017
#     Feature 3304: weight=0.0015
#     Feature 2310: weight=0.0013
#     Feature 3504: weight=0.0008
#     Feature 5797: weight=0.0002
#     Feature 2383: weight=0.0001
#
# Class 90: 16 non-zero features (sorted by weight, positives first)
#     Feature 2418: weight=0.0067
#     Feature 4220: weight=0.0050
#     Feature 3304: weight=0.0049
#     Feature 2212: weight=0.0040
#     Feature 1543: weight=0.0039
#     Feature 3478: weight=0.0032
#     Feature 5505: weight=0.0031
#     Feature 483: weight=0.0025
#     Feature 1611: weight=0.0024
#     Feature 1746: weight=0.0022
#     Feature 1971: weight=0.0022
#     Feature 1555: weight=0.0006
#     Feature 2621: weight=0.0004
#     Feature 5429: weight=0.0004
#     Feature 4967: weight=0.0002
#     Feature 1831: weight=0.0001
#
# Class 91: 10 non-zero features (sorted by weight, positives first)
#     Feature 2684: weight=0.0086
#     Feature 4480: weight=0.0024
#     Feature 5797: weight=0.0021
#     Feature 1971: weight=0.0021
#     Feature 3304: weight=0.0018
#     Feature 3478: weight=0.0015
#     Feature 5594: weight=0.0008
#     Feature 1317: weight=0.0006
#     Feature 3198: weight=0.0006
#     Feature 1611: weight=0.0004
#
# Class 92: 11 non-zero features (sorted by weight, positives first)
#     Feature 1331: weight=0.0113
#     Feature 3393: weight=0.0043
#     Feature 3304: weight=0.0033
#     Feature 3423: weight=0.0015
#     Feature 5594: weight=0.0013
#     Feature 652: weight=0.0008
#     Feature 6009: weight=0.0008
#     Feature 2621: weight=0.0006
#     Feature 1971: weight=0.0004
#     Feature 1611: weight=0.0003
#     Feature 4614: weight=0.0002
#
# Class 93: 2 non-zero features (sorted by weight, positives first)
#     Feature 1294: weight=0.0075
#     Feature 1971: weight=0.0015
#
# Class 94: 28 non-zero features (sorted by weight, positives first)
#     Feature 5357: weight=0.0059
#     Feature 5900: weight=0.0043
#     Feature 627: weight=0.0038
#     Feature 5598: weight=0.0035
#     Feature 5069: weight=0.0035
#     Feature 1971: weight=0.0034
#     Feature 675: weight=0.0031
#     Feature 1641: weight=0.0031
#     Feature 2621: weight=0.0027
#     Feature 2183: weight=0.0027
#     Feature 4955: weight=0.0023
#     Feature 2614: weight=0.0021
#     Feature 5172: weight=0.0017
#     Feature 5721: weight=0.0015
#     Feature 1317: weight=0.0014
#     Feature 3958: weight=0.0014
#     Feature 5594: weight=0.0013
#     Feature 3304: weight=0.0012
#     Feature 1543: weight=0.0010
#     Feature 1027: weight=0.0009
#     Feature 3504: weight=0.0006
#     Feature 1611: weight=0.0005
#     Feature 2684: weight=0.0005
#     Feature 3478: weight=0.0002
#     Feature 210: weight=0.0002
#     Feature 4514: weight=0.0001
#     Feature 2640: weight=0.0001
#     Feature 3625: weight=0.0001
#
# Class 95: 14 non-zero features (sorted by weight, positives first)
#     Feature 5172: weight=0.0035
#     Feature 4514: weight=0.0034
#     Feature 1543: weight=0.0034
#     Feature 1099: weight=0.0026
#     Feature 5357: weight=0.0018
#     Feature 1971: weight=0.0018
#     Feature 3304: weight=0.0014
#     Feature 1611: weight=0.0012
#     Feature 1758: weight=0.0011
#     Feature 5069: weight=0.0007
#     Feature 3979: weight=0.0004
#     Feature 675: weight=0.0002
#     Feature 627: weight=0.0001
#     Feature 5900: weight=0.0001
#
# Class 96: 7 non-zero features (sorted by weight, positives first)
#     Feature 1900: weight=0.0054
#     Feature 5272: weight=0.0031
#     Feature 3304: weight=0.0021
#     Feature 1611: weight=0.0006
#     Feature 2621: weight=0.0004
#     Feature 1758: weight=0.0001
#     Feature 1162: weight=0.0001
#
# Class 97: 11 non-zero features (sorted by weight, positives first)
#     Feature 2396: weight=0.0076
#     Feature 2381: weight=0.0050
#     Feature 3304: weight=0.0033
#     Feature 1141: weight=0.0030
#     Feature 507: weight=0.0025
#     Feature 2295: weight=0.0020
#     Feature 2184: weight=0.0020
#     Feature 1971: weight=0.0015
#     Feature 5594: weight=0.0015
#     Feature 1611: weight=0.0014
#     Feature 2614: weight=0.0010
#
# Class 98: 10 non-zero features (sorted by weight, positives first)
#     Feature 1676: weight=0.0076
#     Feature 2582: weight=0.0039
#     Feature 483: weight=0.0031
#     Feature 3304: weight=0.0028
#     Feature 2141: weight=0.0018
#     Feature 4458: weight=0.0013
#     Feature 1611: weight=0.0012
#     Feature 5797: weight=0.0009
#     Feature 5375: weight=0.0009
#     Feature 5357: weight=0.0001
#
# Class 99: 4 non-zero features (sorted by weight, positives first)
#     Feature 1363: weight=0.0095
#     Feature 3304: weight=0.0036
#     Feature 1971: weight=0.0002
#     Feature 5594: weight=0.0001
#
# ================ IID ==================
#
# Class 0: 23 non-zero features (sorted by weight, positives first)
#     Feature 606: weight=0.0015
#     Feature 4395: weight=0.0015
#     Feature 778: weight=0.0001
#     Feature 2640: weight=0.0001
#     Feature 2621: weight=0.0001
#     Feature 483: weight=0.0001
#     Feature 1411: weight=0.0001
#     Feature 3680: weight=0.0000
#     Feature 4206: weight=0.0000
#     Feature 2077: weight=0.0000
#     Feature 5492: weight=0.0000
#     Feature 1746: weight=0.0000
#     Feature 3304: weight=0.0000
#     Feature 4002: weight=0.0000
#     Feature 210: weight=0.0000
#     Feature 686: weight=0.0000
#     Feature 930: weight=0.0000
#     Feature 466: weight=0.0000
#     Feature 6104: weight=0.0000
#     Feature 264: weight=0.0000
#     Feature 1971: weight=0.0000
#     Feature 1035: weight=0.0000
#     Feature 4753: weight=0.0000
#
# Class 1: 8 non-zero features (sorted by weight, positives first)
#     Feature 521: weight=0.0019
#     Feature 136: weight=0.0016
#     Feature 4261: weight=0.0001
#     Feature 686: weight=0.0001
#     Feature 3304: weight=0.0001
#     Feature 2821: weight=0.0000
#     Feature 757: weight=0.0000
#     Feature 2257: weight=0.0000
#
# Class 2: 34 non-zero features (sorted by weight, positives first)
#     Feature 92: weight=0.0021
#     Feature 2998: weight=0.0016
#     Feature 2028: weight=0.0003
#     Feature 3246: weight=0.0003
#     Feature 5469: weight=0.0002
#     Feature 1831: weight=0.0002
#     Feature 2308: weight=0.0001
#     Feature 3821: weight=0.0001
#     Feature 4721: weight=0.0001
#     Feature 5832: weight=0.0001
#     Feature 4080: weight=0.0001
#     Feature 1001: weight=0.0001
#     Feature 1893: weight=0.0001
#     Feature 5231: weight=0.0001
#     Feature 1226: weight=0.0001
#     Feature 1971: weight=0.0001
#     Feature 3625: weight=0.0001
#     Feature 448: weight=0.0000
#     Feature 5660: weight=0.0000
#     Feature 1905: weight=0.0000
#     Feature 4154: weight=0.0000
#     Feature 3715: weight=0.0000
#     Feature 3304: weight=0.0000
#     Feature 3114: weight=0.0000
#     Feature 3217: weight=0.0000
#     Feature 57: weight=0.0000
#     Feature 1543: weight=0.0000
#     Feature 6104: weight=0.0000
#     Feature 191: weight=0.0000
#     Feature 700: weight=0.0000
#     Feature 4568: weight=0.0000
#     Feature 5741: weight=0.0000
#     Feature 5509: weight=0.0000
#     Feature 2974: weight=0.0000
#
# Class 3: 17 non-zero features (sorted by weight, positives first)
#     Feature 1001: weight=0.0019
#     Feature 4721: weight=0.0013
#     Feature 1645: weight=0.0002
#     Feature 2028: weight=0.0001
#     Feature 2128: weight=0.0001
#     Feature 5636: weight=0.0001
#     Feature 2581: weight=0.0000
#     Feature 1971: weight=0.0000
#     Feature 4989: weight=0.0000
#     Feature 92: weight=0.0000
#     Feature 1543: weight=0.0000
#     Feature 531: weight=0.0000
#     Feature 3633: weight=0.0000
#     Feature 3737: weight=0.0000
#     Feature 5205: weight=0.0000
#     Feature 28: weight=0.0000
#     Feature 5662: weight=0.0000
#
# Class 4: 40 non-zero features (sorted by weight, positives first)
#     Feature 5636: weight=0.0023
#     Feature 2128: weight=0.0010
#     Feature 5509: weight=0.0006
#     Feature 1746: weight=0.0002
#     Feature 2581: weight=0.0002
#     Feature 4000: weight=0.0002
#     Feature 5205: weight=0.0002
#     Feature 5076: weight=0.0001
#     Feature 2076: weight=0.0001
#     Feature 2473: weight=0.0001
#     Feature 4721: weight=0.0001
#     Feature 2801: weight=0.0001
#     Feature 4989: weight=0.0001
#     Feature 3633: weight=0.0001
#     Feature 4761: weight=0.0001
#     Feature 6054: weight=0.0001
#     Feature 4853: weight=0.0001
#     Feature 2797: weight=0.0001
#     Feature 3304: weight=0.0001
#     Feature 1971: weight=0.0001
#     Feature 201: weight=0.0000
#     Feature 2310: weight=0.0000
#     Feature 4373: weight=0.0000
#     Feature 2224: weight=0.0000
#     Feature 802: weight=0.0000
#     Feature 9: weight=0.0000
#     Feature 5127: weight=0.0000
#     Feature 837: weight=0.0000
#     Feature 1779: weight=0.0000
#     Feature 1001: weight=0.0000
#     Feature 1555: weight=0.0000
#     Feature 851: weight=0.0000
#     Feature 2988: weight=0.0000
#     Feature 4043: weight=0.0000
#     Feature 531: weight=0.0000
#     Feature 5662: weight=0.0000
#     Feature 5231: weight=0.0000
#     Feature 591: weight=0.0000
#     Feature 2023: weight=0.0000
#     Feature 1502: weight=0.0000
#
# Class 5: 27 non-zero features (sorted by weight, positives first)
#     Feature 1919: weight=0.0017
#     Feature 2427: weight=0.0010
#     Feature 1002: weight=0.0009
#     Feature 837: weight=0.0007
#     Feature 3936: weight=0.0001
#     Feature 4761: weight=0.0001
#     Feature 5127: weight=0.0001
#     Feature 764: weight=0.0001
#     Feature 2852: weight=0.0001
#     Feature 938: weight=0.0001
#     Feature 2468: weight=0.0001
#     Feature 3304: weight=0.0001
#     Feature 4989: weight=0.0001
#     Feature 1555: weight=0.0001
#     Feature 1543: weight=0.0000
#     Feature 3492: weight=0.0000
#     Feature 4043: weight=0.0000
#     Feature 4881: weight=0.0000
#     Feature 201: weight=0.0000
#     Feature 4160: weight=0.0000
#     Feature 5509: weight=0.0000
#     Feature 2605: weight=0.0000
#     Feature 1482: weight=0.0000
#     Feature 4675: weight=0.0000
#     Feature 757: weight=0.0000
#     Feature 4967: weight=0.0000
#     Feature 1001: weight=0.0000
#
# Class 6: 24 non-zero features (sorted by weight, positives first)
#     Feature 2427: weight=0.0020
#     Feature 1002: weight=0.0013
#     Feature 3936: weight=0.0003
#     Feature 938: weight=0.0001
#     Feature 1654: weight=0.0001
#     Feature 424: weight=0.0001
#     Feature 3492: weight=0.0001
#     Feature 201: weight=0.0001
#     Feature 2468: weight=0.0001
#     Feature 2852: weight=0.0001
#     Feature 5411: weight=0.0001
#     Feature 1971: weight=0.0001
#     Feature 3346: weight=0.0001
#     Feature 3470: weight=0.0001
#     Feature 4000: weight=0.0001
#     Feature 5509: weight=0.0000
#     Feature 3737: weight=0.0000
#     Feature 2128: weight=0.0000
#     Feature 3304: weight=0.0000
#     Feature 587: weight=0.0000
#     Feature 5825: weight=0.0000
#     Feature 4083: weight=0.0000
#     Feature 3468: weight=0.0000
#     Feature 5797: weight=0.0000
#
# Class 7: 42 non-zero features (sorted by weight, positives first)
#     Feature 3985: weight=0.0017
#     Feature 4783: weight=0.0017
#     Feature 854: weight=0.0003
#     Feature 2646: weight=0.0001
#     Feature 1175: weight=0.0001
#     Feature 1543: weight=0.0001
#     Feature 4017: weight=0.0001
#     Feature 1835: weight=0.0000
#     Feature 2537: weight=0.0000
#     Feature 3227: weight=0.0000
#     Feature 3853: weight=0.0000
#     Feature 2605: weight=0.0000
#     Feature 1971: weight=0.0000
#     Feature 5737: weight=0.0000
#     Feature 3304: weight=0.0000
#     Feature 5724: weight=0.0000
#     Feature 435: weight=0.0000
#     Feature 5631: weight=0.0000
#     Feature 4041: weight=0.0000
#     Feature 706: weight=0.0000
# ...
#
# Class 19: 3 common non-zero features (sorted by avg weight)
#     Feature 352: OOD=0.0027, IID=0.0022
#     Feature 4391: OOD=0.0021, IID=0.0007
#     Feature 1971: OOD=0.0005, IID=0.0000
#
# Class 20: 2 common non-zero features (sorted by avg weight)
#     Feature 6039: OOD=0.0052, IID=0.0016
#     Feature 5239: OOD=0.0010, IID=0.0012
#
# Class 21: 3 common non-zero features (sorted by avg weight)
#     Feature 4954: OOD=0.0059, IID=0.0035
#     Feature 473: OOD=0.0023, IID=0.0001
#     Feature 1971: OOD=0.0012, IID=0.0001
#
# Class 22: 5 common non-zero features (sorted by avg weight)
#     Feature 323: OOD=0.0051, IID=0.0020
#     Feature 97: OOD=0.0041, IID=0.0006
#     Feature 1971: OOD=0.0040, IID=0.0001
#     Feature 1543: OOD=0.0040, IID=0.0000
#     Feature 3304: OOD=0.0033, IID=0.0001
#
# Class 23: 11 common non-zero features (sorted by avg weight)
#     Feature 1511: OOD=0.0053, IID=0.0018
#     Feature 2666: OOD=0.0068, IID=0.0001
#     Feature 5868: OOD=0.0046, IID=0.0018
#     Feature 4967: OOD=0.0037, IID=0.0000
#     Feature 1543: OOD=0.0030, IID=0.0001
#     Feature 1971: OOD=0.0030, IID=0.0001
#     Feature 323: OOD=0.0021, IID=0.0004
#     Feature 3304: OOD=0.0024, IID=0.0001
#     Feature 97: OOD=0.0007, IID=0.0001
#     Feature 2621: OOD=0.0004, IID=0.0000
#     Feature 1947: OOD=0.0002, IID=0.0000
#
# Class 24: 5 common non-zero features (sorted by avg weight)
#     Feature 1498: OOD=0.0136, IID=0.0032
#     Feature 1543: OOD=0.0052, IID=0.0000
#     Feature 3304: OOD=0.0030, IID=0.0001
#     Feature 2360: OOD=0.0011, IID=0.0000
#     Feature 4098: OOD=0.0002, IID=0.0001
#
# Class 25: 5 common non-zero features (sorted by avg weight)
#     Feature 549: OOD=0.0025, IID=0.0023
#     Feature 2360: OOD=0.0016, IID=0.0011
#     Feature 1971: OOD=0.0022, IID=0.0000
#     Feature 3304: OOD=0.0014, IID=0.0000
#     Feature 1947: OOD=0.0004, IID=0.0001
#
# Class 26: 4 common non-zero features (sorted by avg weight)
#     Feature 573: OOD=0.0087, IID=0.0029
#     Feature 2887: OOD=0.0055, IID=0.0006
#     Feature 3304: OOD=0.0024, IID=0.0001
#     Feature 1971: OOD=0.0013, IID=0.0000
#
# Class 27: 4 common non-zero features (sorted by avg weight)
#     Feature 1945: OOD=0.0048, IID=0.0021
#     Feature 5614: OOD=0.0040, IID=0.0009
#     Feature 1971: OOD=0.0020, IID=0.0000
#     Feature 5797: OOD=0.0002, IID=0.0001
#
# Class 28: 5 common non-zero features (sorted by avg weight)
#     Feature 2105: OOD=0.0030, IID=0.0029
#     Feature 1037: OOD=0.0039, IID=0.0002
#     Feature 4816: OOD=0.0029, IID=0.0000
#     Feature 3304: OOD=0.0023, IID=0.0000
#     Feature 1971: OOD=0.0010, IID=0.0001
#
# Class 29: 3 common non-zero features (sorted by avg weight)
#     Feature 354: OOD=0.0035, IID=0.0026
#     Feature 3304: OOD=0.0014, IID=0.0001
#     Feature 1971: OOD=0.0010, IID=0.0000
#
# Class 30: 0 common non-zero features (sorted by avg weight)
#
# Class 31: 3 common non-zero features (sorted by avg weight)
#     Feature 1206: OOD=0.0025, IID=0.0019
#     Feature 505: OOD=0.0035, IID=0.0009
#     Feature 1971: OOD=0.0018, IID=0.0001
#
# Class 32: 2 common non-zero features (sorted by avg weight)
#     Feature 3245: OOD=0.0027, IID=0.0025
#     Feature 5252: OOD=0.0028, IID=0.0007
#
# Class 33: 2 common non-zero features (sorted by avg weight)
#     Feature 1971: OOD=0.0025, IID=0.0001
#     Feature 2791: OOD=0.0002, IID=0.0000
#
# Class 34: 1 common non-zero features (sorted by avg weight)
#     Feature 1971: OOD=0.0027, IID=0.0001
#
# Class 35: 0 common non-zero features (sorted by avg weight)
#
# Class 36: 4 common non-zero features (sorted by avg weight)
#     Feature 2004: OOD=0.0003, IID=0.0028
#     Feature 1971: OOD=0.0026, IID=0.0001
#     Feature 4160: OOD=0.0012, IID=0.0009
#     Feature 3304: OOD=0.0003, IID=0.0001
#
# Class 37: 2 common non-zero features (sorted by avg weight)
#     Feature 2791: OOD=0.0035, IID=0.0022
#     Feature 3262: OOD=0.0024, IID=0.0010
#
# Class 38: 4 common non-zero features (sorted by avg weight)
#     Feature 4123: OOD=0.0015, IID=0.0027
#     Feature 3304: OOD=0.0017, IID=0.0001
#     Feature 1971: OOD=0.0012, IID=0.0002
#     Feature 3941: OOD=0.0003, IID=0.0002
#
# Class 39: 7 common non-zero features (sorted by avg weight)
#     Feature 2938: OOD=0.0060, IID=0.0001
#     Feature 3304: OOD=0.0022, IID=0.0001
#     Feature 5797: OOD=0.0016, IID=0.0000
#     Feature 1971: OOD=0.0007, IID=0.0001
#     Feature 1543: OOD=0.0007, IID=0.0001
#     Feature 2051: OOD=0.0005, IID=0.0000
#     Feature 2262: OOD=0.0004, IID=0.0001
#
# Class 40: 2 common non-zero features (sorted by avg weight)
#     Feature 4444: OOD=0.0053, IID=0.0009
#     Feature 2238: OOD=0.0002, IID=0.0026
#
# Class 41: 0 common non-zero features (sorted by avg weight)
#
# Class 42: 4 common non-zero features (sorted by avg weight)
#     Feature 1428: OOD=0.0084, IID=0.0001
#     Feature 5076: OOD=0.0004, IID=0.0034
#     Feature 3304: OOD=0.0011, IID=0.0000
#     Feature 2004: OOD=0.0005, IID=0.0001
#
# Class 43: 4 common non-zero features (sorted by avg weight)
#     Feature 3744: OOD=0.0042, IID=0.0000
#     Feature 5797: OOD=0.0023, IID=0.0002
#     Feature 1971: OOD=0.0017, IID=0.0001
#     Feature 3304: OOD=0.0007, IID=0.0000
#
# Class 44: 3 common non-zero features (sorted by avg weight)
#     Feature 1969: OOD=0.0015, IID=0.0023
#     Feature 1971: OOD=0.0027, IID=0.0001
#     Feature 4541: OOD=0.0009, IID=0.0014
#
# Class 45: 6 common non-zero features (sorted by avg weight)
#     Feature 3540: OOD=0.0019, IID=0.0024
#     Feature 1971: OOD=0.0022, IID=0.0001
#     Feature 2051: OOD=0.0007, IID=0.0013
#     Feature 3304: OOD=0.0014, IID=0.0001
#     Feature 3744: OOD=0.0004, IID=0.0000
#     Feature 1611: OOD=0.0001, IID=0.0000
#
# Class 46: 9 common non-zero features (sorted by avg weight)
#     Feature 1513: OOD=0.0116, IID=0.0006
#     Feature 5360: OOD=0.0038, IID=0.0001
#     Feature 5865: OOD=0.0011, IID=0.0024
#     Feature 3010: OOD=0.0026, IID=0.0000
#     Feature 1543: OOD=0.0008, IID=0.0002
#     Feature 1971: OOD=0.0002, IID=0.0000
#     Feature 3304: OOD=0.0001, IID=0.0001
#     Feature 5480: OOD=0.0001, IID=0.0002
#     Feature 3404: OOD=0.0001, IID=0.0001
#
# Class 47: 2 common non-zero features (sorted by avg weight)
#     Feature 3825: OOD=0.0087, IID=0.0025
#     Feature 2571: OOD=0.0004, IID=0.0006
#
# Class 48: 7 common non-zero features (sorted by avg weight)
#     Feature 3645: OOD=0.0074, IID=0.0000
#     Feature 2526: OOD=0.0044, IID=0.0014
#     Feature 1381: OOD=0.0051, IID=0.0001
#     Feature 2223: OOD=0.0050, IID=0.0000
#     Feature 6095: OOD=0.0026, IID=0.0018
#     Feature 1971: OOD=0.0017, IID=0.0002
#     Feature 3304: OOD=0.0007, IID=0.0000
#
# Class 49: 6 common non-zero features (sorted by avg weight)
#     Feature 2223: OOD=0.0089, IID=0.0034
#     Feature 6095: OOD=0.0080, IID=0.0010
#     Feature 5480: OOD=0.0043, IID=0.0009
#     Feature 3304: OOD=0.0019, IID=0.0001
#     Feature 1758: OOD=0.0013, IID=0.0000
#     Feature 1971: OOD=0.0009, IID=0.0001
#
# Class 50: 1 common non-zero features (sorted by avg weight)
#     Feature 1971: OOD=0.0010, IID=0.0001
#
# Class 51: 6 common non-zero features (sorted by avg weight)
#     Feature 3010: OOD=0.0108, IID=0.0014
#     Feature 1971: OOD=0.0033, IID=0.0000
#     Feature 5105: OOD=0.0007, IID=0.0018
#     Feature 5865: OOD=0.0014, IID=0.0002
#     Feature 3304: OOD=0.0002, IID=0.0000
#     Feature 1138: OOD=0.0002, IID=0.0000
#
# Class 52: 2 common non-zero features (sorted by avg weight)
#     Feature 1701: OOD=0.0051, IID=0.0019
#     Feature 4747: OOD=0.0049, IID=0.0012
#
# Class 53: 7 common non-zero features (sorted by avg weight)
#     Feature 5480: OOD=0.0089, IID=0.0022
#     Feature 2223: OOD=0.0045, IID=0.0001
#     Feature 183: OOD=0.0029, IID=0.0008
#     Feature 1543: OOD=0.0018, IID=0.0001
#     Feature 1971: OOD=0.0009, IID=0.0001
#     Feature 3304: OOD=0.0002, IID=0.0000
#     Feature 1758: OOD=0.0001, IID=0.0000
#
# Class 54: 4 common non-zero features (sorted by avg weight)
#     Feature 3538: OOD=0.0119, IID=0.0023
#     Feature 1138: OOD=0.0118, IID=0.0011
#     Feature 4435: OOD=0.0068, IID=0.0000
#     Feature 1746: OOD=0.0024, IID=0.0000
#
# Class 55: 2 common non-zero features (sorted by avg weight)
#     Feature 1582: OOD=0.0076, IID=0.0018
#     Feature 6009: OOD=0.0009, IID=0.0011
#
# Class 56: 3 common non-zero features (sorted by avg weight)
#     Feature 4858: OOD=0.0048, IID=0.0018
#     Feature 520: OOD=0.0051, IID=0.0014
#     Feature 1971: OOD=0.0018, IID=0.0000
#
# Class 57: 4 common non-zero features (sorted by avg weight)
#     Feature 5168: OOD=0.0063, IID=0.0012
#     Feature 6009: OOD=0.0041, IID=0.0002
#     Feature 3304: OOD=0.0017, IID=0.0001
#     Feature 1971: OOD=0.0001, IID=0.0000
#
# Class 58: 2 common non-zero features (sorted by avg weight)
#     Feature 1971: OOD=0.0033, IID=0.0000
#     Feature 4822: OOD=0.0014, IID=0.0016
#
# Class 59: 4 common non-zero features (sorted by avg weight)
#     Feature 2827: OOD=0.0072, IID=0.0009
#     Feature 4824: OOD=0.0018, IID=0.0019
#     Feature 1971: OOD=0.0012, IID=0.0000
#     Feature 3304: OOD=0.0006, IID=0.0000
#
# Class 60: 3 common non-zero features (sorted by avg weight)
#     Feature 1262: OOD=0.0025, IID=0.0018
#     Feature 1971: OOD=0.0025, IID=0.0001
#     Feature 5731: OOD=0.0014, IID=0.0009
#
# Class 61: 0 common non-zero features (sorted by avg weight)
#
# Class 62: 1 common non-zero features (sorted by avg weight)
#     Feature 579: OOD=0.0040, IID=0.0020
#
# Class 63: 5 common non-zero features (sorted by avg weight)
#     Feature 2383: OOD=0.0031, IID=0.0021
#     Feature 3304: OOD=0.0025, IID=0.0001
#     Feature 5861: OOD=0.0006, IID=0.0002
#     Feature 4955: OOD=0.0003, IID=0.0001
#     Feature 1971: OOD=0.0001, IID=0.0000
#
# Class 64: 6 common non-zero features (sorted by avg weight)
#     Feature 5472: OOD=0.0043, IID=0.0031
#     Feature 2685: OOD=0.0040, IID=0.0000
#     Feature 5079: OOD=0.0034, IID=0.0000
#     Feature 1971: OOD=0.0020, IID=0.0000
#     Feature 3723: OOD=0.0003, IID=0.0005
#     Feature 3304: OOD=0.0002, IID=0.0000
#
# Class 65: 2 common non-zero features (sorted by avg weight)
#     Feature 6085: OOD=0.0122, IID=0.0026
#     Feature 3304: OOD=0.0009, IID=0.0000
#
# Class 66: 4 common non-zero features (sorted by avg weight)
#     Feature 5079: OOD=0.0051, IID=0.0013
#     Feature 3031: OOD=0.0035, IID=0.0019
#     Feature 1971: OOD=0.0011, IID=0.0000
#     Feature 3304: OOD=0.0002, IID=0.0000
#
# Class 67: 3 common non-zero features (sorted by avg weight)
#     Feature 3585: OOD=0.0056, IID=0.0033
#     Feature 3304: OOD=0.0029, IID=0.0000
#     Feature 1971: OOD=0.0006, IID=0.0001
#
# Class 68: 1 common non-zero features (sorted by avg weight)
#     Feature 4971: OOD=0.0049, IID=0.0033
#
# Class 69: 3 common non-zero features (sorted by avg weight)
#     Feature 1921: OOD=0.0090, IID=0.0009
#     Feature 3304: OOD=0.0025, IID=0.0000
#     Feature 1971: OOD=0.0021, IID=0.0000
#
# Class 70: 3 common non-zero features (sorted by avg weight)
#     Feature 1531: OOD=0.0030, IID=0.0022
#     Feature 1184: OOD=0.0007, IID=0.0006
#     Feature 3304: OOD=0.0009, IID=0.0000
#
# Class 71: 2 common non-zero features (sorted by avg weight)
#     Feature 255: OOD=0.0098, IID=0.0021
#     Feature 1971: OOD=0.0001, IID=0.0000
#
# Class 72: 3 common non-zero features (sorted by avg weight)
#     Feature 5757: OOD=0.0077, IID=0.0012
#     Feature 4703: OOD=0.0066, IID=0.0016
#     Feature 1971: OOD=0.0016, IID=0.0000
#
# Class 73: 3 common non-zero features (sorted by avg weight)
#     Feature 5983: OOD=0.0048, IID=0.0027
#     Feature 5189: OOD=0.0023, IID=0.0012
#     Feature 1971: OOD=0.0027, IID=0.0000
#
# Class 74: 0 common non-zero features (sorted by avg weight)
#
# Class 75: 5 common non-zero features (sorted by avg weight)
#     Feature 3394: OOD=0.0103, IID=0.0024
#     Feature 3734: OOD=0.0059, IID=0.0016
#     Feature 697: OOD=0.0027, IID=0.0002
#     Feature 5797: OOD=0.0012, IID=0.0000
#     Feature 3304: OOD=0.0007, IID=0.0000
#
# Class 76: 4 common non-zero features (sorted by avg weight)
#     Feature 4347: OOD=0.0097, IID=0.0023
#     Feature 1065: OOD=0.0093, IID=0.0011
#     Feature 1543: OOD=0.0035, IID=0.0000
#     Feature 3304: OOD=0.0020, IID=0.0001
#
# Class 77: 3 common non-zero features (sorted by avg weight)
#     Feature 3423: OOD=0.0079, IID=0.0014
#     Feature 1079: OOD=0.0008, IID=0.0020
#     Feature 2982: OOD=0.0005, IID=0.0006
#
# Class 78: 3 common non-zero features (sorted by avg weight)
#     Feature 1971: OOD=0.0028, IID=0.0000
#     Feature 5328: OOD=0.0014, IID=0.0001
#     Feature 1535: OOD=0.0005, IID=0.0000
#
# Class 79: 3 common non-zero features (sorted by avg weight)
#     Feature 2957: OOD=0.0037, IID=0.0025
#     Feature 5797: OOD=0.0034, IID=0.0000
#     Feature 1971: OOD=0.0003, IID=0.0000
#
# Class 80: 2 common non-zero features (sorted by avg weight)
#     Feature 5385: OOD=0.0104, IID=0.0016
#     Feature 6081: OOD=0.0092, IID=0.0009
#
# Class 81: 4 common non-zero features (sorted by avg weight)
#     Feature 1971: OOD=0.0038, IID=0.0001
#     Feature 4398: OOD=0.0024, IID=0.0000
#     Feature 2815: OOD=0.0010, IID=0.0000
#     Feature 3304: OOD=0.0001, IID=0.0001
#
# Class 82: 4 common non-zero features (sorted by avg weight)
#     Feature 67: OOD=0.0026, IID=0.0024
#     Feature 2815: OOD=0.0031, IID=0.0015
#     Feature 3304: OOD=0.0030, IID=0.0001
#     Feature 1971: OOD=0.0002, IID=0.0000
#
# Class 83: 4 common non-zero features (sorted by avg weight)
#     Feature 3395: OOD=0.0052, IID=0.0012
#     Feature 620: OOD=0.0039, IID=0.0016
#     Feature 1971: OOD=0.0017, IID=0.0000
#     Feature 5360: OOD=0.0014, IID=0.0000
#
# Class 84: 2 common non-zero features (sorted by avg weight)
#     Feature 3304: OOD=0.0084, IID=0.0000
#     Feature 3047: OOD=0.0032, IID=0.0026
#
# Class 85: 1 common non-zero features (sorted by avg weight)
#     Feature 1254: OOD=0.0054, IID=0.0026
#
# Class 86: 3 common non-zero features (sorted by avg weight)
#     Feature 3198: OOD=0.0023, IID=0.0023
#     Feature 4959: OOD=0.0005, IID=0.0011
#     Feature 3304: OOD=0.0014, IID=0.0000
#
# Class 87: 4 common non-zero features (sorted by avg weight)
#     Feature 522: OOD=0.0119, IID=0.0021
#     Feature 5797: OOD=0.0015, IID=0.0000
#     Feature 1971: OOD=0.0008, IID=0.0000
#     Feature 3304: OOD=0.0003, IID=0.0000
#
# Class 88: 4 common non-zero features (sorted by avg weight)
#     Feature 4220: OOD=0.0032, IID=0.0010
#     Feature 3783: OOD=0.0014, IID=0.0017
#     Feature 1971: OOD=0.0030, IID=0.0000
#     Feature 1983: OOD=0.0010, IID=0.0001
#
# Class 89: 3 common non-zero features (sorted by avg weight)
#     Feature 728: OOD=0.0110, IID=0.0019
#     Feature 1971: OOD=0.0031, IID=0.0000
#     Feature 3304: OOD=0.0015, IID=0.0000
#
# Class 90: 2 common non-zero features (sorted by avg weight)
#     Feature 2418: OOD=0.0067, IID=0.0024
#     Feature 4220: OOD=0.0050, IID=0.0000
#
# Class 91: 2 common non-zero features (sorted by avg weight)
#     Feature 2684: OOD=0.0086, IID=0.0017
#     Feature 1971: OOD=0.0021, IID=0.0000
#
# Class 92: 2 common non-zero features (sorted by avg weight)
#     Feature 3393: OOD=0.0043, IID=0.0023
#     Feature 4614: OOD=0.0002, IID=0.0009
#
# Class 93: 1 common non-zero features (sorted by avg weight)
#     Feature 1294: OOD=0.0075, IID=0.0017
#
# Class 94: 4 common non-zero features (sorted by avg weight)
#     Feature 5900: OOD=0.0043, IID=0.0017
#     Feature 5598: OOD=0.0035, IID=0.0016
#     Feature 1971: OOD=0.0034, IID=0.0001
#     Feature 3304: OOD=0.0012, IID=0.0000
#
# Class 95: 5 common non-zero features (sorted by avg weight)
#     Feature 4514: OOD=0.0034, IID=0.0028
#     Feature 1099: OOD=0.0026, IID=0.0006
#     Feature 5357: OOD=0.0018, IID=0.0000
#     Feature 5069: OOD=0.0007, IID=0.0000
#     Feature 5900: OOD=0.0001, IID=0.0000
#
# Class 96: 2 common non-zero features (sorted by avg weight)
#     Feature 1900: OOD=0.0054, IID=0.0018
#     Feature 5272: OOD=0.0031, IID=0.0011
#
# Class 97: 4 common non-zero features (sorted by avg weight)
#     Feature 2381: OOD=0.0050, IID=0.0024
#     Feature 1141: OOD=0.0030, IID=0.0007
#     Feature 3304: OOD=0.0033, IID=0.0000
#     Feature 1971: OOD=0.0015, IID=0.0001
#
# Class 98: 4 common non-zero features (sorted by avg weight)
#     Feature 1676: OOD=0.0076, IID=0.0005
#     Feature 2582: OOD=0.0039, IID=0.0020
#     Feature 3304: OOD=0.0028, IID=0.0000
#     Feature 5375: OOD=0.0009, IID=0.0014
#
# Class 99: 3 common non-zero features (sorted by avg weight)
#     Feature 1363: OOD=0.0095, IID=0.0029
#     Feature 3304: OOD=0.0036, IID=0.0001
#     Feature 1971: OOD=0.0002, IID=0.0002

# %%
SAEs = {
    "ViT": sae
}

models = {
    "ViT": ViT(device="cuda")
}

# %%
SAEs = {
    "ViT": sae
}

models = {
    "ViT": ViT(device="cuda")
}

inet_trainloader, _= Load_ImageNet100(transform=None, batch_size=256, shuffle=True, dataset_allow=True, train=True)

activations_dataloader = Load_activation_dataloader(
    models=models,
    image_dataloader=inet_trainloader,
    max_seq_len=196,
    save_dir=f"./activations/ViTMLP_INET",
    generate=True,
    rearrange_string='n t d -> (n t) d'
)

visualize_concepts(
    activation_loader=activations_dataloader,
    SAEs=SAEs,
    save_dir=f"./results/visualize2_VITMLP_INET",
    patch_width=14,
    num_concepts=concepts,
    n_images=4,
    abort_threshold=0.0,
)

# %%
sketch_trainloader = Load_ImageNet100Sketch(transform=None, batch_size=250, shuffle=True, train=True)

activations_dataloader = Load_activation_dataloader(
    models=models,
    image_dataloader=sketch_trainloader,
    max_seq_len=196,
    save_dir=f"./activations/ViTMLP_sketch",
    generate=True,
    rearrange_string='n t d -> (n t) d'
)

visualize_concepts(
    activation_loader=activations_dataloader,
    SAEs=SAEs,
    save_dir=f"./results/visualize2_VITMLP_sketch",
    patch_width=14,
    num_concepts=concepts,
    n_images=8,
    abort_threshold=0.0,
)
# Out:
# Processing Batches:   0%|          | 0/21 [00:00<?, ?it/s]
# <torch.utils.data.dataloader.DataLoader object at 0x0000022E26821AE0>
# Processing Batches: 100%|██████████| 21/21 [00:45<00:00,  2.15s/it]
# Generating Activations
# 100%|██████████| 21/21 [00:55<00:00,  2.62s/it]
# Saving Concepts
# 100%|██████████| 6144/6144 [15:44<00:00,  6.51it/s]
